# %% [markdown]
# # Toro

# %% [markdown]
# ## Importamos la librería:

# %%
import tadasets

# %% [markdown]
# La librería tadasets carga un conjunto de datos siguiendo una estructura topológica: https://tadasets.scikit-tda.org/en/latest/index.html#

# %% [markdown]
# ### Cargamos los datos en forma de toro:

# %%
torus=tadasets.torus(n=2000,c=20,a=0.3,noise=0.3)

# %% [markdown]
# #### Parámetros:
# * n (int): Número de puntos.
# * c (float): Distancia del centro al centro del tubo
# * a (float): Radio del tubo
# * ambient (int, default=None): Encaja el toro en un espacio de dimensión igual a "ambient". El toro es aleatoriamente rotado en este espacio.
# * seed(int, default=None): Semilla para aleatorizar.

# %% [markdown]
# #### Veamos qué estructura tienen:

# %%
torus
# Out:
# array([[ 14.76066715, -14.53070723,   0.69148555],
#        [-18.23420709,   8.3374187 ,   0.06010538],
#        [  6.07185235,  18.95250772,   0.2467855 ],
#        ...,
#        [ 19.94723699,  -0.9064204 ,  -0.45794785],
#        [-18.88025268,   6.34905035,  -0.27734022],
#        [-16.46514991, -12.25633159,   0.04076275]])

# %%
torus.shape
# Out:
# (2000, 3)

# %% [markdown]
# #### ¿Cómo se ven?

# %%
import plotly.graph_objects as go
import plotly.offline as pyo

# Create a trace for the scatter plot
trace = go.Scatter3d(
    x=torus[:, 0], 
    y=torus[:, 1], 
    z=torus[:, 2],
    mode='markers',
    marker=dict(
        size=2,
        color=torus[:, 2],  # set color to an array/list of desired values
        colorscale='Viridis',   # choose a colorscale
        opacity=0.8
    )
)

# Create the layout
layout = go.Layout(
    scene=dict(xaxis=dict(showbackground=False),
               yaxis=dict(showbackground=False),
               zaxis=dict(showbackground=False)),
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=0
    )
)

# Create the Figure and add the scatter plot
fig = go.Figure(data=[trace], layout=layout)

# Save the figure as an HTML file
pyo.plot(fig, filename='TORUS TORO 3D.html', auto_open=True)
# Out:
# 'TORUS TORO 3D.html'

# %% [markdown]
# ## Importamos las librerías:

# %%
import kmapper as km
import numpy as np
import sklearn

# %% [markdown]
# ## Iniciamos el algoritmo:

# %%
mapper=km.KeplerMapper(verbose=3)
# Out:
# KeplerMapper(verbose=3)

# %% [markdown]
# ### Elegimos el filtro:

# %%
lens = mapper.fit_transform(torus)
# Out:
# ..Composing projection pipeline of length 1:
# 	Projections: sum
# 	Distance matrices: False
# 	Scalers: MinMaxScaler()
# ..Projecting on data shaped (2000, 3)
#
# ..Projecting data using: sum
#
# ..Scaling with: MinMaxScaler()

# %% [markdown]
# ### Creamos el nervio

# %%
graph = mapper.map(
    lens,
    torus,
    clusterer=sklearn.cluster.DBSCAN(eps=1, min_samples=3),
    cover=km.Cover(n_cubes=15, perc_overlap=0.4),
)
# Out:
# Mapping on data shaped (2000, 3) using lens shaped (2000, 1)
#
# Minimal points in hypercube before clustering: 3
# Creating 15 hypercubes.
#    > Found 1 clusters in hypercube 0.
#    > Found 2 clusters in hypercube 1.
#    > Found 2 clusters in hypercube 2.
#    > Found 2 clusters in hypercube 3.
#    > Found 2 clusters in hypercube 4.
#    > Found 2 clusters in hypercube 5.
#    > Found 2 clusters in hypercube 6.
#    > Found 2 clusters in hypercube 7.
#    > Found 2 clusters in hypercube 8.
#    > Found 2 clusters in hypercube 9.
#    > Found 2 clusters in hypercube 10.
#    > Found 2 clusters in hypercube 11.
#    > Found 2 clusters in hypercube 12.
#    > Found 3 clusters in hypercube 13.
#    > Found 1 clusters in hypercube 14.
#
# Created 29 edges and 29 nodes in 0:00:00.068999.

# %% [markdown]
# ### Visualizamos

# %%
mapper.visualize(graph, path_html="Torus Sum.html",
                title="lens = mapper.fit_transform(torus)")
# Out:
# Wrote visualization to: Torus DBSCAN.html
# '<!DOCTYPE html>\n<html>\n\n<head>\n  <meta charset="utf-8">\n  <meta name="generator" content="KeplerMapper">\n  <title>lens = mapper.fit_transform(torus) | KeplerMapper</title>\n\n  <link rel="icon" type="image/png" href="http://i.imgur.com/axOG6GJ.jpg" />\n\n  <link href=\'https://fonts.googleapis.com/css?family=Roboto+Mono:700,300\' rel=\'stylesheet\' type=\'text/css\'>\n  <style>* {\n  margin: 0;\n  padding: 0;\n}\n\nhtml, body {\n  height: 100%;\n}\n\nbody {\n  font-family: "Roboto Mono", "Helvetica", sans-serif;\n  font-size: 14px;\n}\n\n#logo {\n  width:  85px;\n  height: 85px;\n}\n\n#display {\n  color: #95A5A6;\n  background: #212121;\n}\n\n#header {\n  background: #111111;\n}\n\n#print {\n  color: #000;\n  background: #FFF;\n}\n\nh1 {\n  font-size: 21px;\n  font-weight: 300;\n  font-weight: 300;\n}\n\nh2 {\n  font-size: 18px;\n  padding-bottom: 20px;\n  font-weight: 300;\n}\n\nh3 {\n  font-size: 14px;\n  font-weight: 700;\n  text-transform: uppercase;\n}\n\nh4 {\n  font-size: 13px;\n  font-weight: 700;\n  text-transform: uppercase;\n  padding-bottom:0px;\n}\n\n\n#meta_content h3 {\n  float: left;\n  padding-right: 8px;\n}\n\np, #tooltip_content h3, ol, ul, table {\n  padding-bottom: 10px;\n}\n\nol, ul {\n  padding-left: 20px;\n}\n\nol b {\n  display: block;\n}\n\na {\n  color: #16a085;\n  text-decoration: none;\n}\n\n.pane {\n  position: relative;\n}\n\n.pane-left {\n  float: left;\n}\n\n.pane-right {\n  float: right;\n}\n\na:hover {\n  color: #2ecc71;\n}\n\n.banner {\n  /* height: 35px; */\n  padding: 10px 0px;\n}\n\n\n#print #header {\n  background: #FFF;\n}\n\n\n#canvas {\n  width: 100%;\n}\n\n#svg {\n  position: absolute;\n}\n\n#toolbar {\n  padding-top: 5px;\n  margin-bottom: 5px;\n  width: 100%;\n}\n\n#display #toolbar {\n}\n\n#display .banner {\n  border-top: 1px solid #000;\n}\n\n.inline-block {\n  display: inline-block;\n}\n\n.tool_item {\n  padding-left: 10px;\n  padding-right: 10px;\n}\n\n.pane_content {\n  width: 300px;\n  height:100%;\n  padding: 20px;\n  overflow: auto;\n  display: none;\n}\n\n.pane {\n  z-index: 1;\n}\n\n#display .pane_content {\n  background: #191919;\n}\n\n#print .pane_content{\n  background: #FFF;\n}\n\n#meta_content::-webkit-scrollbar, #tooltip_content::-webkit-scrollbar {\n  width: 1em;\n}\n\n#meta_content::-webkit-scrollbar-track, #tooltip_content::-webkit-scrollbar-track {\n  -webkit-box-shadow: inset 0 0 6px rgba(0, 0, 0, 0.3);\n}\n\n#meta_content::-webkit-scrollbar-thumb, #tooltip_content::-webkit-scrollbar-thumb {\n  background-color: darkgrey;\n  outline: 1px solid slategrey;\n}\n\n.histogram {\n  display: block;\n  height: 100px;\n  padding-top: 50px;\n  clear: both;\n}\n\n#display .histogram {\n  opacity: 0.68;\n}\n\n.bin {\n  width: 10%;\n  float: left;\n}\n\n.bin div {\n  font-size: 10px;\n  display: block;\n  width: 35px;\n  margin-top: -30px;\n  text-align: right;\n  margin-left: -3px;\n  -webkit-transform: rotate(-90deg);\n  -moz-transform: rotate(-90deg);\n  -ms-transform: rotate(-90deg);\n  -o-transform: rotate(-90deg);\n}\n\n.histogram:hover {\n  opacity: 1.;\n}\n\n#display .circle {\n  stroke-opacity: 0.18;\n  stroke-width: 7px;\n  stroke: #000;\n}\n\n#print .circle {\n  stroke-opacity: 1;\n  stroke-width: 2px;\n  stroke: #000;\n  stroke-linecap: round;\n}\n\n#print .link {\n  stroke: #000;\n}\n\n#display .link {\n  stroke: rgba(160, 160, 160, 0.5);\n}\n\ntable {\n  border-collapse: collapse;\n  display: table;\n  width: 100%;\n  margin-bottom: 20px;\n}\n\ntd, th {\n  padding: 5px;\n  text-align: left;\n}\n\n#display th {\n  background: #212121\n}\n\ntd {\n  border-bottom: 1px solid #111;\n}\n\n.highlight {\n  filter: url(#drop-shadow-pulse);\n}\n\n.control-row {\n  padding: 5px 0px;\n}\n\n.btn {\n  display: inline-block;\n  padding: 0.35em 1.2em;\n  border: 0.1em solid #FFFFFF;\n  margin: 0 0.3em 0.3em 0;\n  border-radius: 0.12em;\n  box-sizing: border-box;\n  text-decoration: none;\n  background-color: transparent;\n  font-weight: 300;\n  color: #FFFFFF;\n  tex ...

# %% [markdown]
# ## ¿Qué otros filtros podemos usar?

# %% [markdown]
# Una clase de sklearn con fit_transform (manifold.TSNE(), KernelDensity, IsolationForest) o funciones como “sum”, “mean”, “median”, “max”, “min”, “std”, “dist_mean”, “l2norm”, “knn_distance_n”

# %% [markdown]
# # "l2norm"

# %%
lens = mapper.fit_transform(torus, projection="l2norm")

graph = mapper.map(
    lens,
    torus,
    clusterer=sklearn.cluster.DBSCAN(eps=1, min_samples=3),
    cover=km.Cover(n_cubes=15, perc_overlap=0.3),
)

mapper.visualize(graph, path_html="Torus l2norm.html",
                 title="l2norm")
# Out:
# ..Composing projection pipeline of length 1:
# 	Projections: l2norm
# 	Distance matrices: False
# 	Scalers: MinMaxScaler()
# ..Projecting on data shaped (2000, 3)
#
# ..Projecting data using: l2norm
#
# ..Scaling with: MinMaxScaler()
#
# Mapping on data shaped (2000, 3) using lens shaped (2000, 1)
#
# Minimal points in hypercube before clustering: 3
# Creating 15 hypercubes.
# Cube_0 is empty.
# c:\Users\herie\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning:
#
# Could not find the number of physical cores for the following reason:
# found 0 physical cores < 1
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#
#   File "c:\Users\herie\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\backend\context.py", line 282, in _count_physical_cores
#     raise ValueError(f"found {cpu_count_physical} physical cores < 1")
#    > Found 0 clusters in hypercube 1.
#    > Found 0 clusters in hypercube 2.
#    > Found 5 clusters in hypercube 3.
#    > Found 24 clusters in hypercube 4.
#    > Found 25 clusters in hypercube 5.
#    > Found 11 clusters in hypercube 6.
#    > Found 11 clusters in hypercube 7.
#    > Found 14 clusters in hypercube 8.
#    > Found 22 clusters in hypercube 9.
#    > Found 26 clusters in hypercube 10.
#    > Found 5 clusters in hypercube 11.
#    > Found 0 clusters in hypercube 12.
# Cube_13 is empty.
#
# Cube_14 is empty.
#
#
# Created 155 edges and 143 nodes in 0:00:00.368284.
# Wrote visualization to: Torus l2norm.html
# '<!DOCTYPE html>\n<html>\n\n<head>\n  <meta charset="utf-8">\n  <meta name="generator" content="KeplerMapper">\n  <title>l2norm | KeplerMapper</title>\n\n  <link rel="icon" type="image/png" href="http://i.imgur.com/axOG6GJ.jpg" />\n\n  <link href=\'https://fonts.googleapis.com/css?family=Roboto+Mono:700,300\' rel=\'stylesheet\' type=\'text/css\'>\n  <style>* {\n  margin: 0;\n  padding: 0;\n}\n\nhtml, body {\n  height: 100%;\n}\n\nbody {\n  font-family: "Roboto Mono", "Helvetica", sans-serif;\n  font-size: 14px;\n}\n\n#logo {\n  width:  85px;\n  height: 85px;\n}\n\n#display {\n  color: #95A5A6;\n  background: #212121;\n}\n\n#header {\n  background: #111111;\n}\n\n#print {\n  color: #000;\n  background: #FFF;\n}\n\nh1 {\n  font-size: 21px;\n  font-weight: 300;\n  font-weight: 300;\n}\n\nh2 {\n  font-size: 18px;\n  padding-bottom: 20px;\n  font-weight: 300;\n}\n\nh3 {\n  font-size: 14px;\n  font-weight: 700;\n  text-transform: uppercase;\n}\n\nh4 {\n  font-size: 13px;\n  font-weight: 700;\n  text-transform: uppercase;\n  padding-bottom:0px;\n}\n\n\n#meta_content h3 {\n  float: left;\n  padding-right: 8px;\n}\n\np, #tooltip_content h3, ol, ul, table {\n  padding-bottom: 10px;\n}\n\nol, ul {\n  padding-left: 20px;\n}\n\nol b {\n  display: block;\n}\n\na {\n  color: #16a085;\n  text-decoration: none;\n}\n\n.pane {\n  position: relative;\n}\n\n.pane-left {\n  float: left;\n}\n\n.pane-right {\n  float: right;\n}\n\na:hover {\n  color: #2ecc71;\n}\n\n.banner {\n  /* height: 35px; */\n  padding: 10px 0px;\n}\n\n\n#print #header {\n  background: #FFF;\n}\n\n\n#canvas {\n  width: 100%;\n}\n\n#svg {\n  position: absolute;\n}\n\n#toolbar {\n  padding-top: 5px;\n  margin-bottom: 5px;\n  width: 100%;\n}\n\n#display #toolbar {\n}\n\n#display .banner {\n  border-top: 1px solid #000;\n}\n\n.inline-block {\n  display: inline-block;\n}\n\n.tool_item {\n  padding-left: 10px;\n  padding-right: 10px;\n}\n\n.pane_content {\n  width: 300px;\n  height:100%;\n  padding: 20px;\n  overflow: auto;\n  display: none;\n}\n\n.pane {\n  z-index: 1;\n}\n\n#display .pane_content {\n  background: #191919;\n}\n\n#print .pane_content{\n  background: #FFF;\n}\n\n#meta_content::-webkit-scrollbar, #tooltip_content::-webkit-scrollbar {\n  width: 1em;\n}\n\n#meta_content::-webkit-scrollbar-track, #tooltip_content::-webkit-scrollbar-track {\n  -webkit-box-shadow: inset 0 0 6px rgba(0, 0, 0, 0.3);\n}\n\n#meta_content::-webkit-scrollbar-thumb, #tooltip_content::-webkit-scrollbar-thumb {\n  background-color: darkgrey;\n  outline: 1px solid slategrey;\n}\n\n.histogram {\n  display: block;\n  height: 100px;\n  padding-top: 50px;\n  clear: both;\n}\n\n#display .histogram {\n  opacity: 0.68;\n}\n\n.bin {\n  width: 10%;\n  float: left;\n}\n\n.bin div {\n  font-size: 10px;\n  display: block;\n  width: 35px;\n  margin-top: -30px;\n  text-align: right;\n  margin-left: -3px;\n  -webkit-transform: rotate(-90deg);\n  -moz-transform: rotate(-90deg);\n  -ms-transform: rotate(-90deg);\n  -o-transform: rotate(-90deg);\n}\n\n.histogram:hover {\n  opacity: 1.;\n}\n\n#display .circle {\n  stroke-opacity: 0.18;\n  stroke-width: 7px;\n  stroke: #000;\n}\n\n#print .circle {\n  stroke-opacity: 1;\n  stroke-width: 2px;\n  stroke: #000;\n  stroke-linecap: round;\n}\n\n#print .link {\n  stroke: #000;\n}\n\n#display .link {\n  stroke: rgba(160, 160, 160, 0.5);\n}\n\ntable {\n  border-collapse: collapse;\n  display: table;\n  width: 100%;\n  margin-bottom: 20px;\n}\n\ntd, th {\n  padding: 5px;\n  text-align: left;\n}\n\n#display th {\n  background: #212121\n}\n\ntd {\n  border-bottom: 1px solid #111;\n}\n\n.highlight {\n  filter: url(#drop-shadow-pulse);\n}\n\n.control-row {\n  padding: 5px 0px;\n}\n\n.btn {\n  display: inline-block;\n  padding: 0.35em 1.2em;\n  border: 0.1em solid #FFFFFF;\n  margin: 0 0.3em 0.3em 0;\n  border-radius: 0.12em;\n  box-sizing: border-box;\n  text-decoration: none;\n  background-color: transparent;\n  font-weight: 300;\n  color: #FFFFFF;\n  text-align: center;\n  transiti ...

# %% [markdown]
# # KernelDensity:

# %% [markdown]
# KernelDensity es un estimador de densidad: https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KernelDensity.html
#
# #### Parámetros:
# * bandwidht (float, Default=1.0): La banda ancha del Kernel.
# * algorithm: El algoritmo a usar ('kd_tree','ball_tree','auto' (Default)
# * kernel: El kernel a usar ('gaussian','topath','epanechnivok',‘exponential’, ‘linear’, ‘cosine’)
# * metric (str, Default='euclidean'): La métrica a usar.

# %%
from sklearn.neighbors import KernelDensity

# Fit a Gaussian Kernel Density Estimator to the data and use it as a lens for the Mapper graph 
lens = mapper.fit_transform(torus, projection=KernelDensity(kernel='gaussian',bandwidth=0.5))

graph = mapper.map(
    lens,
    torus,
    clusterer=sklearn.cluster.DBSCAN(eps=1, min_samples=3),
    cover=km.Cover(n_cubes=10, perc_overlap=0.3),
)

mapper.visualize(graph, path_html="Torus KernelDensity.html",
                 title="KernelDensity")
# Out:
# ..Composing projection pipeline of length 1:
# 	Projections: KernelDensity(bandwidth=0.5)
# 	Distance matrices: False
# 	Scalers: MinMaxScaler()
# ..Projecting on data shaped (2000, 3)
#
# ..Projecting data using:
# 	KernelDensity(bandwidth=0.5)
#
#
# ..Scaling with: MinMaxScaler()
#
# Mapping on data shaped (2000, 3) using lens shaped (2000, 3)
#
# Minimal points in hypercube before clustering: 3
# Creating 1000 hypercubes.
# Cube_0 is empty.
#
#    > Found 1 clusters in hypercube 1.
# Cube_2 is empty.
#
# Cube_3 is empty.
#
# Cube_4 is empty.
#
# Cube_5 is empty.
#
#    > Found 1 clusters in hypercube 6.
#    > Found 1 clusters in hypercube 7.
#    > Found 2 clusters in hypercube 8.
#    > Found 1 clusters in hypercube 9.
#    > Found 1 clusters in hypercube 10.
#    > Found 1 clusters in hypercube 11.
#    > Found 1 clusters in hypercube 12.
# Cube_13 is empty.
#
# Cube_14 is empty.
#
#    > Found 1 clusters in hypercube 15.
#    > Found 2 clusters in hypercube 16.
#    > Found 1 clusters in hypercube 17.
#    > Found 1 clusters in hypercube 18.
#    > Found 2 clusters in hypercube 19.
#    > Found 1 clusters in hypercube 20.
# Cube_21 is empty.
#
# Cube_22 is empty.
#
# Cube_23 is empty.
#
#    > Found 2 clusters in hypercube 24.
#    > Found 1 clusters in hypercube 25.
#    > Found 1 clusters in hypercube 26.
#    > Found 1 clusters in hypercube 27.
#    > Found 1 clusters in hypercube 28.
#    > Found 2 clusters in hypercube 29.
# Cube_30 is empty.
#
# Cube_31 is empty.
#
#    > Found 0 clusters in hypercube 32.
#    > Found 1 clusters in hypercube 33.
#    > Found 1 clusters in hypercube 34.
#    > Found 1 clusters in hypercube 35.
#    > Found 1 clusters in hypercube 36.
#    > Found 1 clusters in hypercube 37.
#    > Found 0 clusters in hypercube 38.
# Cube_39 is empty.
#
# Cube_40 is empty.
#
# Cube_41 is empty.
#
#    > Found 0 clusters in hypercube 42.
#    > Found 1 clusters in hypercube 43.
#    > Found 1 clusters in hypercube 44.
#    > Found 2 clusters in hypercube 45.
#    > Found 2 clusters in hypercube 46.
#    > Found 1 clusters in hypercube 47.
#    > Found 1 clusters in hypercube 48.
#    > Found 0 clusters in hypercube 49.
#    > Found 0 clusters in hypercube 50.
#    > Found 1 clusters in hypercube 51.
#    > Found 2 clusters in hypercube 52.
#    > Found 1 clusters in hypercube 53.
#    > Found 1 clusters in hypercube 54.
#    > Found 1 clusters in hypercube 55.
#    > Found 1 clusters in hypercube 56.
#    > Found 0 clusters in hypercube 57.
# Cube_58 is empty.
#
# Cube_59 is empty.
#
# Cube_60 is empty.
#
# Cube_61 is empty.
#
#    > Found 1 clusters in hypercube 62.
#    > Found 1 clusters in hypercube 63.
#    > Found 1 clusters in hypercube 64.
# Cube_65 is empty.
#
# Cube_66 is empty.
#
# Cube_67 is empty.
#
# Cube_68 is empty.
#
#    > Found 1 clusters in hypercube 69.
#    > Found 1 clusters in hypercube 70.
# Cube_71 is empty.
#
#    > Found 3 clusters in hypercube 72.
#    > Found 1 clusters in hypercube 73.
#    > Found 2 clusters in hypercube 74.
#    > Found 2 clusters in hypercube 75.
#    > Found 2 clusters in hypercube 76.
#    > Found 1 clusters in hypercube 77.
# Cube_78 is empty.
#
# Cube_79 is empty.
#
#    > Found 1 clusters in hypercube 80.
#    > Found 3 clusters in hypercube 81.
#    > Found 1 clusters in hypercube 82.
#    > Found 1 clusters in hypercube 83.
#    > Found 2 clusters in hypercube 84.
#    > Found 2 clusters in hypercube 85.
# Cube_86 is empty.
#
#    > Found 1 clusters in hypercube 87.
# Cube_88 is empty.
#
# Cube_89 is empty.
#
# Cube_90 is empty.
#
# Cube_91 is empty.
#
# Cube_92 is empty.
#
# Cube_93 is empty.
#
# Cube_94 is empty.
#
#    > Found 1 clusters in hypercube 95.
#    > Found 1 clusters in hypercube 96.
#    > Found 2 clusters in hypercube 97.
#    > Found 1 clusters in hypercube 98.
#    > Found 1 clusters in hypercube 99.
#    > Found 2 clusters in hypercube 100.
#    > Found 0 clusters in hypercube 101.
# Cube_102 is empty.
#
# Cube_103 is empty.
#
#    > Found 0 clusters in hypercube 104.
#    > Found 1 clusters in hypercube 105.
#    > Found 2 clusters in hypercube 106.
#    > Found 1 clusters in hypercube 107.
#    > Found 1 clusters in hypercube 108.
#    > Found 2 clusters in hypercube 109.
#    > Found 2 clusters in hypercube 110.
#    > Found 0 clusters in hypercube 111.
# Cube_112 is empty.
#
# Cube_113 is empty.
#
#    > Found 1 clusters in hypercube 114.
#    > Found 1 clusters in hypercube 115.
#    > Found 1 clusters in hypercube 116.
#    > Found 1 clusters in hypercube 117.
#    > Found 1 clusters in hypercube 118.
# Cube_119 is empty.
#
# Cube_120 is empty.
#
# Cube_121 is empty.
#
#    > Found 0 clusters in hypercube 122.
#    > Found 1 clusters in hypercube 123.
#    > Found 2 clusters in hypercube 124.
#    > Found 1 clusters in hypercube 125.
#    > Found 1 clusters in hypercube 126.
#    > Found 1 clusters in hypercube 127.
#    > Found 0 clusters in hypercube 128.
#    > Found 0 clusters in hypercube 129.
# Cube_130 is empty.
#
# Cube_131 is empty.
#
#    > Found 2 clusters in hypercube 132.
#    > Found 3 clusters in hypercube 133.
#    > Found 1 clusters in hypercube 134.
#    > Found 1 clusters in hypercube 135.
#    > Found 1 clusters in hypercube 136.
#    > Found 1 clusters in hypercube 137.
#    > Found 0 clusters in hypercube 138.
# Cube_139 is empty.
#
#    > Found 0 clusters in hypercube 140.
#    > Found 2 clusters in hypercube 141.
#    > Found 1 clusters in hypercube 142.
#    > Found 1 clusters in hypercube 143.
#    > Found 1 clusters in hypercube 144.
#    > Found 1 clusters in hypercube 145.
# Cube_146 is empty.
#
# Cube_147 is empty.
#
# Cube_148 is empty.
#
#    > Found 1 clusters in hypercube 149.
#    > Found 1 clusters in hypercube 150.
#    > Found 1 clusters in hypercube 151.
#    > Found 1 clusters in hypercube 152.
#    > Found 2 clusters in hypercube 153.
#    > Found 1 clusters in hypercube 154.
#    > Found 0 clusters in hypercube 155.
# Cube_156 is empty.
#
# Cube_157 is empty.
#
# Cube_158 is empty.
#
#    > Found 2 clusters in hypercube 159.
#    > Found 2 clusters in hypercube 160.
#    > Found 1 clusters in hypercube 161.
#    > Found 1 clusters in hypercube 162.
#    > Found 1 clusters in hypercube 163.
#    > Found 1 clusters in hypercube 164.
#    > Found 1 clusters in hypercube 165.
#    > Found 1 clusters in hypercube 166.
# Cube_167 is empty.
#
#    > Found 1 clusters in hypercube 168.
#    > Found 1 clusters in hypercube 169.
#    > Found 1 clusters in hypercube 170.
# Cube_171 is empty.
#
#    > Found 0 clusters in hypercube 172.
#    > Found 0 clusters in hypercube 173.
#    > Found 2 clusters in hypercube 174.
#    > Found 2 clusters in hypercube 175.
#    > Found 1 clusters in hypercube 176.
#    > Found 2 clusters in hypercube 177.
#    > Found 1 clusters in hypercube 178.
#    > Found 0 clusters in hypercube 179.
# Cube_180 is empty.
#
# Cube_181 is empty.
#
#    > Found 2 clusters in hypercube 182.
#    > Found 2 clusters in hypercube 183.
#    > Found 2 clusters in hypercube 184.
#    > Found 2 clusters in hypercube 185.
#    > Found 1 clusters in hypercube 186.
#    > Found 1 clusters in hypercube 187.
#    > Found 1 clusters in hypercube 188.
# Cube_189 is empty.
#
#    > Found 0 clusters in hypercube 190.
#    > Found 1 clusters in hypercube 191.
#    > Found 3 clusters in hypercube 192.
#    > Found 2 clusters in hypercube 193.
#    > Found 1 clusters in hypercube 194.
#    > Found 1 clusters in hypercube 195.
#    > Found 2 clusters in hypercube 196.
#    > Found 0 clusters in hypercube 197.
#    > Found 1 clusters in hypercube 198.
#    > Found 3 clusters in hypercube 199.
#    > Found 1 clusters in hypercube 200.
#    > Found 1 clusters in hypercube 201.
#    > Found 1 clusters in hypercube 202.
#    > Found 1 clusters in hypercube 203.
#    > Found 1 clusters in hypercube 204.
# Cube_205 is empty.
#
# Cube_206 is empty.
#
# Cube_207 is empty.
#
#    > Found 1 clusters in hypercube 208.
#    > Found 2 clusters in hypercube 209.
#    > Found 1 clusters in hypercube 210.
#    > Found 1 clusters in hypercube 211.
#    > Found 1 clusters in hypercube 212.
#    > Found 2 clusters in hypercube 213.
# Cube_214 is empty.
#
# Cube_215 is empty.
#
#    > Found 0 clusters in hypercube 216.
#    > Found 2 clusters in hypercube 217.
#    > Found 2 clusters in hypercube 218.
#    > Found 1 clusters in hypercube 219.
#    > Found 1 clusters in hypercube 220.
#    > Found 2 clusters in hypercube 221.
#    > Found 2 clusters in hypercube 222.
#    > Found 1 clusters in hypercube 223.
# Cube_224 is empty.
#
# Cube_225 is empty.
#
#    > Found 1 clusters in hypercube 226.
#    > Found 1 clusters in hypercube 227.
#    > Found 1 clusters in hypercube 228.
#    > Found 1 clusters in hypercube 229.
# Cube_230 is empty.
#
# Cube_231 is empty.
#
# Cube_232 is empty.
#
# Cube_233 is empty.
#
#    > Found 0 clusters in hypercube 234.
#    > Found 3 clusters in hypercube 235.
#    > Found 2 clusters in hypercube 236.
#    > Found 1 clusters in hypercube 237.
#    > Found 2 clusters in hypercube 238.
#    > Found 2 clusters in hypercube 239.
#    > Found 2 clusters in hypercube 240.
# Cube_241 is empty.
#
#    > Found 0 clusters in hypercube 242.
#    > Found 2 clusters in hypercube 243.
#    > Found 1 clusters in hypercube 244.
#    > Found 1 clusters in hypercube 245.
#    > Found 1 clusters in hypercube 246.
#    > Found 2 clusters in hypercube 247.
#    > Found 0 clusters in hypercube 248.
# Cube_249 is empty.
#
#    > Found 1 clusters in hypercube 250.
#    > Found 3 clusters in hypercube 251.
#    > Found 1 clusters in hypercube 252.
#    > Found 1 clusters in hypercube 253.
#    > Found 1 clusters in hypercube 254.
#    > Found 1 clusters in hypercube 255.
#    > Found 1 clusters in hypercube 256.
# Cube_257 is empty.
#
# Cube_258 is empty.
#
# Cube_259 is empty.
#
#    > Found 1 clusters in hypercube 260.
#    > Found 1 clusters in hypercube 261.
#    > Found 1 clusters in hypercube 262.
#    > Found 2 clusters in hypercube 263.
#    > Found 1 clusters in hypercube 264.
#    > Found 1 clusters in hypercube 265.
#    > Found 0 clusters in hypercube 266.
# Cube_267 is empty.
#
#    > Found 1 clusters in hypercube 268.
#    > Found 1 clusters in hypercube 269.
#    > Found 1 clusters in hypercube 270.
#    > Found 2 clusters in hypercube 271.
#    > Found 2 clusters in hypercube 272.
#    > Found 1 clusters in hypercube 273.
#    > Found 0 clusters in hypercube 274.
# Cube_275 is empty.
#
# Cube_276 is empty.
#
# Cube_277 is empty.
#
# Cube_278 is empty.
#
# Cube_279 is empty.
#
# Cube_280 is empty.
#
# Cube_281 is empty.
#
#    > Found 1 clusters in hypercube 282.
#    > Found 2 clusters in hypercube 283.
#    > Found 1 clusters in hypercube 284.
#    > Found 1 clusters in hypercube 285.
#    > Found 1 clusters in hypercube 286.
#    > Found 1 clusters in hypercube 287.
#    > Found 1 clusters in hypercube 288.
#    > Found 0 clusters in hypercube 289.
# Cube_290 is empty.
#
# Cube_291 is empty.
#
#    > Found 1 clusters in hypercube 292.
#    > Found 1 clusters in hypercube 293.
#    > Found 1 clusters in hypercube 294.
#    > Found 1 clusters in hypercube 295.
#    > Found 1 clusters in hypercube 296.
#    > Found 3 clusters in hypercube 297.
#    > Found 1 clusters in hypercube 298.
#    > Found 1 clusters in hypercube 299.
# Cube_300 is empty.
#
# Cube_301 is empty.
#
#    > Found 1 clusters in hypercube 302.
#    > Found 1 clusters in hypercube 303.
#    > Found 0 clusters in hypercube 304.
# Cube_305 is empty.
#
# Cube_306 is empty.
#
# Cube_307 is empty.
#
# Cube_308 is empty.
#
# Cube_309 is empty.
#
#    > Found 1 clusters in hypercube 310.
#    > Found 1 clusters in hypercube 311.
#    > Found 1 clusters in hypercube 312.
#    > Found 1 clusters in hypercube 313.
#    > Found 1 clusters in hypercube 314.
#    > Found 2 clusters in hypercube 315.
#    > Found 1 clusters in hypercube 316.
# Cube_317 is empty.
#
# Cube_318 is empty.
#
#    > Found 1 clusters in hypercube 319.
#    > Found 2 clusters in hypercube 320.
#    > Found 2 clusters in hypercube 321.
#    > Found 1 clusters in hypercube 322.
#    > Found 2 clusters in hypercube 323.
#    > Found 1 clusters in hypercube 324.
# Cube_325 is empty.
#
#    > Found 1 clusters in hypercube 326.
#    > Found 1 clusters in hypercube 327.
# Cube_328 is empty.
#
# Cube_329 is empty.
#
# Cube_330 is empty.
#
# Cube_331 is empty.
#
# Cube_332 is empty.
#
# Cube_333 is empty.
#
# Cube_334 is empty.
#
# Cube_335 is empty.
#
# Cube_336 is empty.
#
# Cube_337 is empty.
#
#    > Found 1 clusters in hypercube 338.
#    > Found 2 clusters in hypercube 339.
#    > Found 2 clusters in hypercube 340.
#    > Found 1 clusters in hypercube 341.
#    > Found 1 clusters in hypercube 342.
#    > Found 2 clusters in hypercube 343.
#    > Found 1 clusters in hypercube 344.
#    > Found 1 clusters in hypercube 345.
# Cube_346 is empty.
#
# Cube_347 is empty.
#
#    > Found 1 clusters in hypercube 348.
#    > Found 2 clusters in hypercube 349.
#    > Found 2 clusters in hypercube 350.
#    > Found 1 clusters in hypercube 351.
#    > Found 1 clusters in hypercube 352.
#    > Found 2 clusters in hypercube 353.
#    > Found 3 clusters in hypercube 354.
# Cube_355 is empty.
#
# Cube_356 is empty.
#
#    > Found 0 clusters in hypercube 357.
#    > Found 0 clusters in hypercube 358.
#    > Found 2 clusters in hypercube 359.
#    > Found 2 clusters in hypercube 360.
#    > Found 1 clusters in hypercube 361.
#    > Found 1 clusters in hypercube 362.
#    > Found 1 clusters in hypercube 363.
#    > Found 2 clusters in hypercube 364.
# Cube_365 is empty.
#
# Cube_366 is empty.
#
#    > Found 0 clusters in hypercube 367.
#    > Found 2 clusters in hypercube 368.
#    > Found 1 clusters in hypercube 369.
#    > Found 1 clusters in hypercube 370.
#    > Found 1 clusters in hypercube 371.
#    > Found 1 clusters in hypercube 372.
#    > Found 2 clusters in hypercube 373.
# Cube_374 is empty.
#
# Cube_375 is empty.
#
# Cube_376 is empty.
#
#    > Found 2 clusters in hypercube 377.
#    > Found 1 clusters in hypercube 378.
#    > Found 1 clusters in hypercube 379.
#    > Found 2 clusters in hypercube 380.
#    > Found 3 clusters in hypercube 381.
#    > Found 2 clusters in hypercube 382.
# Cube_383 is empty.
#
#    > Found 1 clusters in hypercube 384.
#    > Found 1 clusters in hypercube 385.
#    > Found 1 clusters in hypercube 386.
#    > Found 1 clusters in hypercube 387.
#    > Found 1 clusters in hypercube 388.
#    > Found 1 clusters in hypercube 389.
#    > Found 1 clusters in hypercube 390.
# Cube_391 is empty.
#
#    > Found 1 clusters in hypercube 392.
#    > Found 1 clusters in hypercube 393.
#    > Found 1 clusters in hypercube 394.
#    > Found 1 clusters in hypercube 395.
# Cube_396 is empty.
#
#
# Created 1109 edges and 340 nodes in 0:00:00.633861.
# Wrote visualization to: Torus KernelDensity.html
# '<!DOCTYPE html>\n<html>\n\n<head>\n  <meta charset="utf-8">\n  <meta name="generator" content="KeplerMapper">\n  <title>KernelDensity | KeplerMapper</title>\n\n  <link rel="icon" type="image/png" href="http://i.imgur.com/axOG6GJ.jpg" />\n\n  <link href=\'https://fonts.googleapis.com/css?family=Roboto+Mono:700,300\' rel=\'stylesheet\' type=\'text/css\'>\n  <style>* {\n  margin: 0;\n  padding: 0;\n}\n\nhtml, body {\n  height: 100%;\n}\n\nbody {\n  font-family: "Roboto Mono", "Helvetica", sans-serif;\n  font-size: 14px;\n}\n\n#logo {\n  width:  85px;\n  height: 85px;\n}\n\n#display {\n  color: #95A5A6;\n  background: #212121;\n}\n\n#header {\n  background: #111111;\n}\n\n#print {\n  color: #000;\n  background: #FFF;\n}\n\nh1 {\n  font-size: 21px;\n  font-weight: 300;\n  font-weight: 300;\n}\n\nh2 {\n  font-size: 18px;\n  padding-bottom: 20px;\n  font-weight: 300;\n}\n\nh3 {\n  font-size: 14px;\n  font-weight: 700;\n  text-transform: uppercase;\n}\n\nh4 {\n  font-size: 13px;\n  font-weight: 700;\n  text-transform: uppercase;\n  padding-bottom:0px;\n}\n\n\n#meta_content h3 {\n  float: left;\n  padding-right: 8px;\n}\n\np, #tooltip_content h3, ol, ul, table {\n  padding-bottom: 10px;\n}\n\nol, ul {\n  padding-left: 20px;\n}\n\nol b {\n  display: block;\n}\n\na {\n  color: #16a085;\n  text-decoration: none;\n}\n\n.pane {\n  position: relative;\n}\n\n.pane-left {\n  float: left;\n}\n\n.pane-right {\n  float: right;\n}\n\na:hover {\n  color: #2ecc71;\n}\n\n.banner {\n  /* height: 35px; */\n  padding: 10px 0px;\n}\n\n\n#print #header {\n  background: #FFF;\n}\n\n\n#canvas {\n  width: 100%;\n}\n\n#svg {\n  position: absolute;\n}\n\n#toolbar {\n  padding-top: 5px;\n  margin-bottom: 5px;\n  width: 100%;\n}\n\n#display #toolbar {\n}\n\n#display .banner {\n  border-top: 1px solid #000;\n}\n\n.inline-block {\n  display: inline-block;\n}\n\n.tool_item {\n  padding-left: 10px;\n  padding-right: 10px;\n}\n\n.pane_content {\n  width: 300px;\n  height:100%;\n  padding: 20px;\n  overflow: auto;\n  display: none;\n}\n\n.pane {\n  z-index: 1;\n}\n\n#display .pane_content {\n  background: #191919;\n}\n\n#print .pane_content{\n  background: #FFF;\n}\n\n#meta_content::-webkit-scrollbar, #tooltip_content::-webkit-scrollbar {\n  width: 1em;\n}\n\n#meta_content::-webkit-scrollbar-track, #tooltip_content::-webkit-scrollbar-track {\n  -webkit-box-shadow: inset 0 0 6px rgba(0, 0, 0, 0.3);\n}\n\n#meta_content::-webkit-scrollbar-thumb, #tooltip_content::-webkit-scrollbar-thumb {\n  background-color: darkgrey;\n  outline: 1px solid slategrey;\n}\n\n.histogram {\n  display: block;\n  height: 100px;\n  padding-top: 50px;\n  clear: both;\n}\n\n#display .histogram {\n  opacity: 0.68;\n}\n\n.bin {\n  width: 10%;\n  float: left;\n}\n\n.bin div {\n  font-size: 10px;\n  display: block;\n  width: 35px;\n  margin-top: -30px;\n  text-align: right;\n  margin-left: -3px;\n  -webkit-transform: rotate(-90deg);\n  -moz-transform: rotate(-90deg);\n  -ms-transform: rotate(-90deg);\n  -o-transform: rotate(-90deg);\n}\n\n.histogram:hover {\n  opacity: 1.;\n}\n\n#display .circle {\n  stroke-opacity: 0.18;\n  stroke-width: 7px;\n  stroke: #000;\n}\n\n#print .circle {\n  stroke-opacity: 1;\n  stroke-width: 2px;\n  stroke: #000;\n  stroke-linecap: round;\n}\n\n#print .link {\n  stroke: #000;\n}\n\n#display .link {\n  stroke: rgba(160, 160, 160, 0.5);\n}\n\ntable {\n  border-collapse: collapse;\n  display: table;\n  width: 100%;\n  margin-bottom: 20px;\n}\n\ntd, th {\n  padding: 5px;\n  text-align: left;\n}\n\n#display th {\n  background: #212121\n}\n\ntd {\n  border-bottom: 1px solid #111;\n}\n\n.highlight {\n  filter: url(#drop-shadow-pulse);\n}\n\n.control-row {\n  padding: 5px 0px;\n}\n\n.btn {\n  display: inline-block;\n  padding: 0.35em 1.2em;\n  border: 0.1em solid #FFFFFF;\n  margin: 0 0.3em 0.3em 0;\n  border-radius: 0.12em;\n  box-sizing: border-box;\n  text-decoration: none;\n  background-color: transparent;\n  font-weight: 300;\n  color: #FFFFFF;\n  text-align: center;\n  t ...

# %% [markdown]
# # IsolationForest

# %% [markdown]
# Es una manera de detectar valores atípicos (outliers) en conjuntos de datos de dimensiones mayores: https://scikit-learn.org/stable/modules/outlier_detection.html#isolation-forest

# %% [markdown]
# #### Parámetros
# * n_estimators (int, Default=100): El número de estimadores base.
# * max_samples ('auto', int o float, default='auto'): El número de muestras a dibujar de $X$ para entrenar cada estimador base.
# * random_state (int, default=None): Controla la "seudo aleatoridad" de la selección de la característica.

# %%
from sklearn import ensemble

model = ensemble.IsolationForest(random_state=1729)
model.fit(torus)
lens1 = model.decision_function(torus).reshape((torus.shape[0], 1))

graph = mapper.map(
    lens,
    torus,
    clusterer=sklearn.cluster.DBSCAN(eps=1, min_samples=3),
    cover=km.Cover(n_cubes=10, perc_overlap=0.3),
)

mapper.visualize(graph, path_html="Torus IsolationForest.html",
                    title="IsolationForest")
# Out:
# Mapping on data shaped (2000, 3) using lens shaped (2000, 3)
#
# Minimal points in hypercube before clustering: 3
# Creating 1000 hypercubes.
# Cube_0 is empty.
#
#    > Found 1 clusters in hypercube 1.
# Cube_2 is empty.
#
# Cube_3 is empty.
#
# Cube_4 is empty.
#
# Cube_5 is empty.
#
#    > Found 1 clusters in hypercube 6.
#    > Found 1 clusters in hypercube 7.
#    > Found 2 clusters in hypercube 8.
#    > Found 1 clusters in hypercube 9.
#    > Found 1 clusters in hypercube 10.
#    > Found 1 clusters in hypercube 11.
#    > Found 1 clusters in hypercube 12.
# Cube_13 is empty.
#
# Cube_14 is empty.
#
#    > Found 1 clusters in hypercube 15.
#    > Found 2 clusters in hypercube 16.
#    > Found 1 clusters in hypercube 17.
#    > Found 1 clusters in hypercube 18.
#    > Found 2 clusters in hypercube 19.
#    > Found 1 clusters in hypercube 20.
# Cube_21 is empty.
#
# Cube_22 is empty.
#
# Cube_23 is empty.
#
#    > Found 2 clusters in hypercube 24.
#    > Found 1 clusters in hypercube 25.
#    > Found 1 clusters in hypercube 26.
#    > Found 1 clusters in hypercube 27.
#    > Found 1 clusters in hypercube 28.
#    > Found 2 clusters in hypercube 29.
# Cube_30 is empty.
#
# Cube_31 is empty.
#
#    > Found 0 clusters in hypercube 32.
#    > Found 1 clusters in hypercube 33.
#    > Found 1 clusters in hypercube 34.
#    > Found 1 clusters in hypercube 35.
#    > Found 1 clusters in hypercube 36.
#    > Found 1 clusters in hypercube 37.
#    > Found 0 clusters in hypercube 38.
# Cube_39 is empty.
#
# Cube_40 is empty.
#
# Cube_41 is empty.
#
#    > Found 0 clusters in hypercube 42.
#    > Found 1 clusters in hypercube 43.
#    > Found 1 clusters in hypercube 44.
#    > Found 2 clusters in hypercube 45.
#    > Found 2 clusters in hypercube 46.
#    > Found 1 clusters in hypercube 47.
#    > Found 1 clusters in hypercube 48.
#    > Found 0 clusters in hypercube 49.
#    > Found 0 clusters in hypercube 50.
#    > Found 1 clusters in hypercube 51.
#    > Found 2 clusters in hypercube 52.
#    > Found 1 clusters in hypercube 53.
#    > Found 1 clusters in hypercube 54.
#    > Found 1 clusters in hypercube 55.
#    > Found 1 clusters in hypercube 56.
#    > Found 0 clusters in hypercube 57.
# Cube_58 is empty.
#
# Cube_59 is empty.
#
# Cube_60 is empty.
#
# Cube_61 is empty.
#
#    > Found 1 clusters in hypercube 62.
#    > Found 1 clusters in hypercube 63.
#    > Found 1 clusters in hypercube 64.
# Cube_65 is empty.
#
# Cube_66 is empty.
#
# Cube_67 is empty.
#
# Cube_68 is empty.
#
#    > Found 1 clusters in hypercube 69.
#    > Found 1 clusters in hypercube 70.
# Cube_71 is empty.
#
#    > Found 3 clusters in hypercube 72.
#    > Found 1 clusters in hypercube 73.
#    > Found 2 clusters in hypercube 74.
#    > Found 2 clusters in hypercube 75.
#    > Found 2 clusters in hypercube 76.
#    > Found 1 clusters in hypercube 77.
# Cube_78 is empty.
#
# Cube_79 is empty.
#
#    > Found 1 clusters in hypercube 80.
#    > Found 3 clusters in hypercube 81.
#    > Found 1 clusters in hypercube 82.
#    > Found 1 clusters in hypercube 83.
#    > Found 2 clusters in hypercube 84.
#    > Found 2 clusters in hypercube 85.
# Cube_86 is empty.
#
#    > Found 1 clusters in hypercube 87.
# Cube_88 is empty.
#
# Cube_89 is empty.
#
# Cube_90 is empty.
#
# Cube_91 is empty.
#
# Cube_92 is empty.
#
# Cube_93 is empty.
#
# Cube_94 is empty.
#
#    > Found 1 clusters in hypercube 95.
#    > Found 1 clusters in hypercube 96.
#    > Found 2 clusters in hypercube 97.
#    > Found 1 clusters in hypercube 98.
#    > Found 1 clusters in hypercube 99.
#    > Found 2 clusters in hypercube 100.
#    > Found 0 clusters in hypercube 101.
# Cube_102 is empty.
#
# Cube_103 is empty.
#
#    > Found 0 clusters in hypercube 104.
#    > Found 1 clusters in hypercube 105.
#    > Found 2 clusters in hypercube 106.
#    > Found 1 clusters in hypercube 107.
#    > Found 1 clusters in hypercube 108.
#    > Found 2 clusters in hypercube 109.
#    > Found 2 clusters in hypercube 110.
#    > Found 0 clusters in hypercube 111.
# Cube_112 is empty.
#
# Cube_113 is empty.
#
#    > Found 1 clusters in hypercube 114.
#    > Found 1 clusters in hypercube 115.
#    > Found 1 clusters in hypercube 116.
#    > Found 1 clusters in hypercube 117.
#    > Found 1 clusters in hypercube 118.
# Cube_119 is empty.
#
# Cube_120 is empty.
#
# Cube_121 is empty.
#
#    > Found 0 clusters in hypercube 122.
#    > Found 1 clusters in hypercube 123.
#    > Found 2 clusters in hypercube 124.
#    > Found 1 clusters in hypercube 125.
#    > Found 1 clusters in hypercube 126.
#    > Found 1 clusters in hypercube 127.
#    > Found 0 clusters in hypercube 128.
#    > Found 0 clusters in hypercube 129.
# Cube_130 is empty.
#
# Cube_131 is empty.
#
#    > Found 2 clusters in hypercube 132.
#    > Found 3 clusters in hypercube 133.
#    > Found 1 clusters in hypercube 134.
#    > Found 1 clusters in hypercube 135.
#    > Found 1 clusters in hypercube 136.
#    > Found 1 clusters in hypercube 137.
#    > Found 0 clusters in hypercube 138.
# Cube_139 is empty.
#
#    > Found 0 clusters in hypercube 140.
#    > Found 2 clusters in hypercube 141.
#    > Found 1 clusters in hypercube 142.
#    > Found 1 clusters in hypercube 143.
#    > Found 1 clusters in hypercube 144.
#    > Found 1 clusters in hypercube 145.
# Cube_146 is empty.
#
# Cube_147 is empty.
#
# Cube_148 is empty.
#
#    > Found 1 clusters in hypercube 149.
#    > Found 1 clusters in hypercube 150.
#    > Found 1 clusters in hypercube 151.
#    > Found 1 clusters in hypercube 152.
#    > Found 2 clusters in hypercube 153.
#    > Found 1 clusters in hypercube 154.
#    > Found 0 clusters in hypercube 155.
# Cube_156 is empty.
#
# Cube_157 is empty.
#
# Cube_158 is empty.
#
#    > Found 2 clusters in hypercube 159.
#    > Found 2 clusters in hypercube 160.
#    > Found 1 clusters in hypercube 161.
#    > Found 1 clusters in hypercube 162.
#    > Found 1 clusters in hypercube 163.
#    > Found 1 clusters in hypercube 164.
#    > Found 1 clusters in hypercube 165.
#    > Found 1 clusters in hypercube 166.
# Cube_167 is empty.
#
#    > Found 1 clusters in hypercube 168.
#    > Found 1 clusters in hypercube 169.
#    > Found 1 clusters in hypercube 170.
# Cube_171 is empty.
#
#    > Found 0 clusters in hypercube 172.
#    > Found 0 clusters in hypercube 173.
#    > Found 2 clusters in hypercube 174.
#    > Found 2 clusters in hypercube 175.
#    > Found 1 clusters in hypercube 176.
#    > Found 2 clusters in hypercube 177.
#    > Found 1 clusters in hypercube 178.
#    > Found 0 clusters in hypercube 179.
# Cube_180 is empty.
#
# Cube_181 is empty.
#
#    > Found 2 clusters in hypercube 182.
#    > Found 2 clusters in hypercube 183.
#    > Found 2 clusters in hypercube 184.
#    > Found 2 clusters in hypercube 185.
#    > Found 1 clusters in hypercube 186.
#    > Found 1 clusters in hypercube 187.
#    > Found 1 clusters in hypercube 188.
# Cube_189 is empty.
#
#    > Found 0 clusters in hypercube 190.
#    > Found 1 clusters in hypercube 191.
#    > Found 3 clusters in hypercube 192.
#    > Found 2 clusters in hypercube 193.
#    > Found 1 clusters in hypercube 194.
#    > Found 1 clusters in hypercube 195.
#    > Found 2 clusters in hypercube 196.
#    > Found 0 clusters in hypercube 197.
#    > Found 1 clusters in hypercube 198.
#    > Found 3 clusters in hypercube 199.
#    > Found 1 clusters in hypercube 200.
#    > Found 1 clusters in hypercube 201.
#    > Found 1 clusters in hypercube 202.
#    > Found 1 clusters in hypercube 203.
#    > Found 1 clusters in hypercube 204.
# Cube_205 is empty.
#
# Cube_206 is empty.
#
# Cube_207 is empty.
#
#    > Found 1 clusters in hypercube 208.
#    > Found 2 clusters in hypercube 209.
#    > Found 1 clusters in hypercube 210.
#    > Found 1 clusters in hypercube 211.
#    > Found 1 clusters in hypercube 212.
#    > Found 2 clusters in hypercube 213.
# Cube_214 is empty.
#
# Cube_215 is empty.
#
#    > Found 0 clusters in hypercube 216.
#    > Found 2 clusters in hypercube 217.
#    > Found 2 clusters in hypercube 218.
#    > Found 1 clusters in hypercube 219.
#    > Found 1 clusters in hypercube 220.
#    > Found 2 clusters in hypercube 221.
#    > Found 2 clusters in hypercube 222.
#    > Found 1 clusters in hypercube 223.
# Cube_224 is empty.
#
# Cube_225 is empty.
#
#    > Found 1 clusters in hypercube 226.
#    > Found 1 clusters in hypercube 227.
#    > Found 1 clusters in hypercube 228.
#    > Found 1 clusters in hypercube 229.
# Cube_230 is empty.
#
# Cube_231 is empty.
#
# Cube_232 is empty.
#
# Cube_233 is empty.
#
#    > Found 0 clusters in hypercube 234.
#    > Found 3 clusters in hypercube 235.
#    > Found 2 clusters in hypercube 236.
#    > Found 1 clusters in hypercube 237.
#    > Found 2 clusters in hypercube 238.
#    > Found 2 clusters in hypercube 239.
#    > Found 2 clusters in hypercube 240.
# Cube_241 is empty.
#
#    > Found 0 clusters in hypercube 242.
#    > Found 2 clusters in hypercube 243.
#    > Found 1 clusters in hypercube 244.
#    > Found 1 clusters in hypercube 245.
#    > Found 1 clusters in hypercube 246.
#    > Found 2 clusters in hypercube 247.
#    > Found 0 clusters in hypercube 248.
# Cube_249 is empty.
#
#    > Found 1 clusters in hypercube 250.
#    > Found 3 clusters in hypercube 251.
#    > Found 1 clusters in hypercube 252.
#    > Found 1 clusters in hypercube 253.
#    > Found 1 clusters in hypercube 254.
#    > Found 1 clusters in hypercube 255.
#    > Found 1 clusters in hypercube 256.
# Cube_257 is empty.
#
# Cube_258 is empty.
#
# Cube_259 is empty.
#
#    > Found 1 clusters in hypercube 260.
#    > Found 1 clusters in hypercube 261.
#    > Found 1 clusters in hypercube 262.
#    > Found 2 clusters in hypercube 263.
#    > Found 1 clusters in hypercube 264.
#    > Found 1 clusters in hypercube 265.
#    > Found 0 clusters in hypercube 266.
# Cube_267 is empty.
#
#    > Found 1 clusters in hypercube 268.
#    > Found 1 clusters in hypercube 269.
#    > Found 1 clusters in hypercube 270.
#    > Found 2 clusters in hypercube 271.
#    > Found 2 clusters in hypercube 272.
#    > Found 1 clusters in hypercube 273.
#    > Found 0 clusters in hypercube 274.
# Cube_275 is empty.
#
# Cube_276 is empty.
#
# Cube_277 is empty.
#
# Cube_278 is empty.
#
# Cube_279 is empty.
#
# Cube_280 is empty.
#
# Cube_281 is empty.
#
#    > Found 1 clusters in hypercube 282.
#    > Found 2 clusters in hypercube 283.
#    > Found 1 clusters in hypercube 284.
#    > Found 1 clusters in hypercube 285.
#    > Found 1 clusters in hypercube 286.
#    > Found 1 clusters in hypercube 287.
#    > Found 1 clusters in hypercube 288.
#    > Found 0 clusters in hypercube 289.
# Cube_290 is empty.
#
# Cube_291 is empty.
#
#    > Found 1 clusters in hypercube 292.
#    > Found 1 clusters in hypercube 293.
#    > Found 1 clusters in hypercube 294.
#    > Found 1 clusters in hypercube 295.
#    > Found 1 clusters in hypercube 296.
#    > Found 3 clusters in hypercube 297.
#    > Found 1 clusters in hypercube 298.
#    > Found 1 clusters in hypercube 299.
# Cube_300 is empty.
#
# Cube_301 is empty.
#
#    > Found 1 clusters in hypercube 302.
#    > Found 1 clusters in hypercube 303.
#    > Found 0 clusters in hypercube 304.
# Cube_305 is empty.
#
# Cube_306 is empty.
#
# Cube_307 is empty.
#
# Cube_308 is empty.
#
# Cube_309 is empty.
#
#    > Found 1 clusters in hypercube 310.
#    > Found 1 clusters in hypercube 311.
#    > Found 1 clusters in hypercube 312.
#    > Found 1 clusters in hypercube 313.
#    > Found 1 clusters in hypercube 314.
#    > Found 2 clusters in hypercube 315.
#    > Found 1 clusters in hypercube 316.
# Cube_317 is empty.
#
# Cube_318 is empty.
#
#    > Found 1 clusters in hypercube 319.
#    > Found 2 clusters in hypercube 320.
#    > Found 2 clusters in hypercube 321.
#    > Found 1 clusters in hypercube 322.
#    > Found 2 clusters in hypercube 323.
#    > Found 1 clusters in hypercube 324.
# Cube_325 is empty.
#
#    > Found 1 clusters in hypercube 326.
#    > Found 1 clusters in hypercube 327.
# Cube_328 is empty.
#
# Cube_329 is empty.
#
# Cube_330 is empty.
#
# Cube_331 is empty.
#
# Cube_332 is empty.
#
# Cube_333 is empty.
#
# Cube_334 is empty.
#
# Cube_335 is empty.
#
# Cube_336 is empty.
#
# Cube_337 is empty.
#
#    > Found 1 clusters in hypercube 338.
#    > Found 2 clusters in hypercube 339.
#    > Found 2 clusters in hypercube 340.
#    > Found 1 clusters in hypercube 341.
#    > Found 1 clusters in hypercube 342.
#    > Found 2 clusters in hypercube 343.
#    > Found 1 clusters in hypercube 344.
#    > Found 1 clusters in hypercube 345.
# Cube_346 is empty.
#
# Cube_347 is empty.
#
#    > Found 1 clusters in hypercube 348.
#    > Found 2 clusters in hypercube 349.
#    > Found 2 clusters in hypercube 350.
#    > Found 1 clusters in hypercube 351.
#    > Found 1 clusters in hypercube 352.
#    > Found 2 clusters in hypercube 353.
#    > Found 3 clusters in hypercube 354.
# Cube_355 is empty.
#
# Cube_356 is empty.
#
#    > Found 0 clusters in hypercube 357.
#    > Found 0 clusters in hypercube 358.
#    > Found 2 clusters in hypercube 359.
#    > Found 2 clusters in hypercube 360.
#    > Found 1 clusters in hypercube 361.
#    > Found 1 clusters in hypercube 362.
#    > Found 1 clusters in hypercube 363.
#    > Found 2 clusters in hypercube 364.
# Cube_365 is empty.
#
# Cube_366 is empty.
#
#    > Found 0 clusters in hypercube 367.
#    > Found 2 clusters in hypercube 368.
#    > Found 1 clusters in hypercube 369.
#    > Found 1 clusters in hypercube 370.
#    > Found 1 clusters in hypercube 371.
#    > Found 1 clusters in hypercube 372.
#    > Found 2 clusters in hypercube 373.
# Cube_374 is empty.
#
# Cube_375 is empty.
#
# Cube_376 is empty.
#
#    > Found 2 clusters in hypercube 377.
#    > Found 1 clusters in hypercube 378.
#    > Found 1 clusters in hypercube 379.
#    > Found 2 clusters in hypercube 380.
#    > Found 3 clusters in hypercube 381.
#    > Found 2 clusters in hypercube 382.
# Cube_383 is empty.
#
#    > Found 1 clusters in hypercube 384.
#    > Found 1 clusters in hypercube 385.
#    > Found 1 clusters in hypercube 386.
#    > Found 1 clusters in hypercube 387.
#    > Found 1 clusters in hypercube 388.
#    > Found 1 clusters in hypercube 389.
#    > Found 1 clusters in hypercube 390.
# Cube_391 is empty.
#
#    > Found 1 clusters in hypercube 392.
#    > Found 1 clusters in hypercube 393.
#    > Found 1 clusters in hypercube 394.
#    > Found 1 clusters in hypercube 395.
# Cube_396 is empty.
#
#
# Created 1109 edges and 340 nodes in 0:00:01.024479.
# Wrote visualization to: Torus IsolationForest.html
# '<!DOCTYPE html>\n<html>\n\n<head>\n  <meta charset="utf-8">\n  <meta name="generator" content="KeplerMapper">\n  <title>IsolationForest | KeplerMapper</title>\n\n  <link rel="icon" type="image/png" href="http://i.imgur.com/axOG6GJ.jpg" />\n\n  <link href=\'https://fonts.googleapis.com/css?family=Roboto+Mono:700,300\' rel=\'stylesheet\' type=\'text/css\'>\n  <style>* {\n  margin: 0;\n  padding: 0;\n}\n\nhtml, body {\n  height: 100%;\n}\n\nbody {\n  font-family: "Roboto Mono", "Helvetica", sans-serif;\n  font-size: 14px;\n}\n\n#logo {\n  width:  85px;\n  height: 85px;\n}\n\n#display {\n  color: #95A5A6;\n  background: #212121;\n}\n\n#header {\n  background: #111111;\n}\n\n#print {\n  color: #000;\n  background: #FFF;\n}\n\nh1 {\n  font-size: 21px;\n  font-weight: 300;\n  font-weight: 300;\n}\n\nh2 {\n  font-size: 18px;\n  padding-bottom: 20px;\n  font-weight: 300;\n}\n\nh3 {\n  font-size: 14px;\n  font-weight: 700;\n  text-transform: uppercase;\n}\n\nh4 {\n  font-size: 13px;\n  font-weight: 700;\n  text-transform: uppercase;\n  padding-bottom:0px;\n}\n\n\n#meta_content h3 {\n  float: left;\n  padding-right: 8px;\n}\n\np, #tooltip_content h3, ol, ul, table {\n  padding-bottom: 10px;\n}\n\nol, ul {\n  padding-left: 20px;\n}\n\nol b {\n  display: block;\n}\n\na {\n  color: #16a085;\n  text-decoration: none;\n}\n\n.pane {\n  position: relative;\n}\n\n.pane-left {\n  float: left;\n}\n\n.pane-right {\n  float: right;\n}\n\na:hover {\n  color: #2ecc71;\n}\n\n.banner {\n  /* height: 35px; */\n  padding: 10px 0px;\n}\n\n\n#print #header {\n  background: #FFF;\n}\n\n\n#canvas {\n  width: 100%;\n}\n\n#svg {\n  position: absolute;\n}\n\n#toolbar {\n  padding-top: 5px;\n  margin-bottom: 5px;\n  width: 100%;\n}\n\n#display #toolbar {\n}\n\n#display .banner {\n  border-top: 1px solid #000;\n}\n\n.inline-block {\n  display: inline-block;\n}\n\n.tool_item {\n  padding-left: 10px;\n  padding-right: 10px;\n}\n\n.pane_content {\n  width: 300px;\n  height:100%;\n  padding: 20px;\n  overflow: auto;\n  display: none;\n}\n\n.pane {\n  z-index: 1;\n}\n\n#display .pane_content {\n  background: #191919;\n}\n\n#print .pane_content{\n  background: #FFF;\n}\n\n#meta_content::-webkit-scrollbar, #tooltip_content::-webkit-scrollbar {\n  width: 1em;\n}\n\n#meta_content::-webkit-scrollbar-track, #tooltip_content::-webkit-scrollbar-track {\n  -webkit-box-shadow: inset 0 0 6px rgba(0, 0, 0, 0.3);\n}\n\n#meta_content::-webkit-scrollbar-thumb, #tooltip_content::-webkit-scrollbar-thumb {\n  background-color: darkgrey;\n  outline: 1px solid slategrey;\n}\n\n.histogram {\n  display: block;\n  height: 100px;\n  padding-top: 50px;\n  clear: both;\n}\n\n#display .histogram {\n  opacity: 0.68;\n}\n\n.bin {\n  width: 10%;\n  float: left;\n}\n\n.bin div {\n  font-size: 10px;\n  display: block;\n  width: 35px;\n  margin-top: -30px;\n  text-align: right;\n  margin-left: -3px;\n  -webkit-transform: rotate(-90deg);\n  -moz-transform: rotate(-90deg);\n  -ms-transform: rotate(-90deg);\n  -o-transform: rotate(-90deg);\n}\n\n.histogram:hover {\n  opacity: 1.;\n}\n\n#display .circle {\n  stroke-opacity: 0.18;\n  stroke-width: 7px;\n  stroke: #000;\n}\n\n#print .circle {\n  stroke-opacity: 1;\n  stroke-width: 2px;\n  stroke: #000;\n  stroke-linecap: round;\n}\n\n#print .link {\n  stroke: #000;\n}\n\n#display .link {\n  stroke: rgba(160, 160, 160, 0.5);\n}\n\ntable {\n  border-collapse: collapse;\n  display: table;\n  width: 100%;\n  margin-bottom: 20px;\n}\n\ntd, th {\n  padding: 5px;\n  text-align: left;\n}\n\n#display th {\n  background: #212121\n}\n\ntd {\n  border-bottom: 1px solid #111;\n}\n\n.highlight {\n  filter: url(#drop-shadow-pulse);\n}\n\n.control-row {\n  padding: 5px 0px;\n}\n\n.btn {\n  display: inline-block;\n  padding: 0.35em 1.2em;\n  border: 0.1em solid #FFFFFF;\n  margin: 0 0.3em 0.3em 0;\n  border-radius: 0.12em;\n  box-sizing: border-box;\n  text-decoration: none;\n  background-color: transparent;\n  font-weight: 300;\n  color: #FFFFFF;\n  text-align: center;\n  ...

# %% [markdown]
# ## Más de un flitro:

# %%
from sklearn.neighbors import KernelDensity
lens1 = mapper.fit_transform(torus, projection=KernelDensity(kernel='gaussian',bandwidth=0.5))
lens2 = mapper.fit_transform(torus, projection="l2norm")

# Combine lenses to get a 2-D lens
lens = np.c_[lens1, lens2]

graph = mapper.map(
    lens,
    torus,
    clusterer=sklearn.cluster.DBSCAN(eps=1, min_samples=3),
    cover=km.Cover(n_cubes=10, perc_overlap=0.3),
)

mapper.visualize(graph, path_html="Torus Gaussian & l2norm.html",
                 title="Gaussian & l2norm lenses")
# Out:
# ..Composing projection pipeline of length 1:
# 	Projections: KernelDensity(bandwidth=0.5)
# 	Distance matrices: False
# 	Scalers: MinMaxScaler()
# ..Projecting on data shaped (2000, 3)
#
# ..Projecting data using:
# 	KernelDensity(bandwidth=0.5)
#
#
# ..Scaling with: MinMaxScaler()
#
# ..Composing projection pipeline of length 1:
# 	Projections: l2norm
# 	Distance matrices: False
# 	Scalers: MinMaxScaler()
# ..Projecting on data shaped (2000, 3)
#
# ..Projecting data using: l2norm
#
# ..Scaling with: MinMaxScaler()
#
# Mapping on data shaped (2000, 3) using lens shaped (2000, 4)
#
# Minimal points in hypercube before clustering: 3
# Creating 10000 hypercubes.
# Cube_0 is empty.
#
# Cube_1 is empty.
#
# Cube_2 is empty.
#
# Cube_3 is empty.
#
# Cube_4 is empty.
#
# Cube_5 is empty.
#
# Cube_6 is empty.
#
# Cube_7 is empty.
#
# Cube_8 is empty.
#
# Cube_9 is empty.
#
# Cube_10 is empty.
#
# Cube_11 is empty.
#
# Cube_12 is empty.
#
# Cube_13 is empty.
#
#    > Found 1 clusters in hypercube 14.
# Cube_15 is empty.
#
# Cube_16 is empty.
#
#    > Found 2 clusters in hypercube 17.
#    > Found 1 clusters in hypercube 18.
# Cube_19 is empty.
#
# Cube_20 is empty.
#
# Cube_21 is empty.
#
# Cube_22 is empty.
#
# Cube_23 is empty.
#
#    > Found 2 clusters in hypercube 24.
#    > Found 1 clusters in hypercube 25.
# Cube_26 is empty.
#
# Cube_27 is empty.
#
# Cube_28 is empty.
#
# Cube_29 is empty.
#
#    > Found 1 clusters in hypercube 30.
#    > Found 1 clusters in hypercube 31.
#    > Found 1 clusters in hypercube 32.
#    > Found 0 clusters in hypercube 33.
# Cube_34 is empty.
#
# Cube_35 is empty.
#
#    > Found 1 clusters in hypercube 36.
#    > Found 1 clusters in hypercube 37.
#    > Found 2 clusters in hypercube 38.
#    > Found 2 clusters in hypercube 39.
#    > Found 0 clusters in hypercube 40.
# Cube_41 is empty.
#
# Cube_42 is empty.
#
# Cube_43 is empty.
#
#    > Found 1 clusters in hypercube 44.
#    > Found 1 clusters in hypercube 45.
#    > Found 2 clusters in hypercube 46.
#    > Found 1 clusters in hypercube 47.
#    > Found 1 clusters in hypercube 48.
# Cube_49 is empty.
#
# Cube_50 is empty.
#
# Cube_51 is empty.
#
# Cube_52 is empty.
#
#    > Found 0 clusters in hypercube 53.
#    > Found 1 clusters in hypercube 54.
#    > Found 0 clusters in hypercube 55.
# Cube_56 is empty.
#
# Cube_57 is empty.
#
# Cube_58 is empty.
#
# Cube_59 is empty.
#
# Cube_60 is empty.
#
# Cube_61 is empty.
#
#    > Found 2 clusters in hypercube 62.
#    > Found 2 clusters in hypercube 63.
#    > Found 0 clusters in hypercube 64.
# Cube_65 is empty.
#
# Cube_66 is empty.
#
#    > Found 0 clusters in hypercube 67.
#    > Found 2 clusters in hypercube 68.
#    > Found 1 clusters in hypercube 69.
#    > Found 0 clusters in hypercube 70.
# Cube_71 is empty.
#
# Cube_72 is empty.
#
# Cube_73 is empty.
#
#    > Found 1 clusters in hypercube 74.
#    > Found 1 clusters in hypercube 75.
#    > Found 1 clusters in hypercube 76.
#    > Found 2 clusters in hypercube 77.
#    > Found 1 clusters in hypercube 78.
# Cube_79 is empty.
#
#    > Found 1 clusters in hypercube 80.
#    > Found 1 clusters in hypercube 81.
#    > Found 1 clusters in hypercube 82.
#    > Found 2 clusters in hypercube 83.
#    > Found 0 clusters in hypercube 84.
# Cube_85 is empty.
#
# Cube_86 is empty.
#
# Cube_87 is empty.
#
#    > Found 0 clusters in hypercube 88.
#    > Found 1 clusters in hypercube 89.
#    > Found 1 clusters in hypercube 90.
# Cube_91 is empty.
#
#    > Found 1 clusters in hypercube 92.
# Cube_93 is empty.
#
# Cube_94 is empty.
#
# Cube_95 is empty.
#
#    > Found 0 clusters in hypercube 96.
#    > Found 0 clusters in hypercube 97.
#    > Found 0 clusters in hypercube 98.
# Cube_99 is empty.
#
# Cube_100 is empty.
#
# Cube_101 is empty.
#
# Cube_102 is empty.
#
# Cube_103 is empty.
#
# Cube_104 is empty.
#
#    > Found 0 clusters in hypercube 105.
#    > Found 1 clusters in hypercube 106.
#    > Found 1 clusters in hypercube 107.
# Cube_108 is empty.
#
#    > Found 1 clusters in hypercube 109.
#    > Found 1 clusters in hypercube 110.
#    > Found 1 clusters in hypercube 111.
#    > Found 0 clusters in hypercube 112.
# Cube_113 is empty.
#
#    > Found 1 clusters in hypercube 114.
#    > Found 2 clusters in hypercube 115.
#    > Found 1 clusters in hypercube 116.
#    > Found 1 clusters in hypercube 117.
#    > Found 1 clusters in hypercube 118.
# Cube_119 is empty.
#
#    > Found 1 clusters in hypercube 120.
#    > Found 1 clusters in hypercube 121.
#    > Found 1 clusters in hypercube 122.
#    > Found 1 clusters in hypercube 123.
#    > Found 0 clusters in hypercube 124.
# Cube_125 is empty.
#
# Cube_126 is empty.
#
#    > Found 0 clusters in hypercube 127.
#    > Found 1 clusters in hypercube 128.
#    > Found 1 clusters in hypercube 129.
#    > Found 0 clusters in hypercube 130.
# Cube_131 is empty.
#
# Cube_132 is empty.
#
#    > Found 0 clusters in hypercube 133.
#    > Found 1 clusters in hypercube 134.
#    > Found 1 clusters in hypercube 135.
# Cube_136 is empty.
#
# Cube_137 is empty.
#
# Cube_138 is empty.
#
# Cube_139 is empty.
#
# Cube_140 is empty.
#
# Cube_141 is empty.
#
# Cube_142 is empty.
#
#    > Found 1 clusters in hypercube 143.
#    > Found 0 clusters in hypercube 144.
#    > Found 2 clusters in hypercube 145.
#    > Found 1 clusters in hypercube 146.
#    > Found 0 clusters in hypercube 147.
#    > Found 1 clusters in hypercube 148.
#    > Found 1 clusters in hypercube 149.
#    > Found 1 clusters in hypercube 150.
#    > Found 0 clusters in hypercube 151.
#    > Found 0 clusters in hypercube 152.
#    > Found 1 clusters in hypercube 153.
#    > Found 2 clusters in hypercube 154.
#    > Found 1 clusters in hypercube 155.
# Cube_156 is empty.
#
# Cube_157 is empty.
#
# Cube_158 is empty.
#
#    > Found 1 clusters in hypercube 159.
#    > Found 1 clusters in hypercube 160.
#    > Found 2 clusters in hypercube 161.
#    > Found 1 clusters in hypercube 162.
#    > Found 0 clusters in hypercube 163.
#    > Found 0 clusters in hypercube 164.
#    > Found 1 clusters in hypercube 165.
#    > Found 1 clusters in hypercube 166.
#    > Found 1 clusters in hypercube 167.
#    > Found 1 clusters in hypercube 168.
# Cube_169 is empty.
#
# Cube_170 is empty.
#
# Cube_171 is empty.
#
#    > Found 0 clusters in hypercube 172.
# Cube_173 is empty.
#
# Cube_174 is empty.
#
# Cube_175 is empty.
#
# Cube_176 is empty.
#
# Cube_177 is empty.
#
# Cube_178 is empty.
#
# Cube_179 is empty.
#
# Cube_180 is empty.
#
# Cube_181 is empty.
#
# Cube_182 is empty.
#
# Cube_183 is empty.
#
# Cube_184 is empty.
#
#    > Found 0 clusters in hypercube 185.
# Cube_186 is empty.
#
# Cube_187 is empty.
#
# Cube_188 is empty.
#
#    > Found 0 clusters in hypercube 189.
#    > Found 1 clusters in hypercube 190.
#    > Found 0 clusters in hypercube 191.
# Cube_192 is empty.
#
# Cube_193 is empty.
#
# Cube_194 is empty.
#
#    > Found 0 clusters in hypercube 195.
#    > Found 1 clusters in hypercube 196.
#    > Found 2 clusters in hypercube 197.
#    > Found 1 clusters in hypercube 198.
# Cube_199 is empty.
#
# Cube_200 is empty.
#
#    > Found 0 clusters in hypercube 201.
#    > Found 1 clusters in hypercube 202.
#    > Found 2 clusters in hypercube 203.
#    > Found 2 clusters in hypercube 204.
#    > Found 1 clusters in hypercube 205.
# Cube_206 is empty.
#
#    > Found 1 clusters in hypercube 207.
#    > Found 1 clusters in hypercube 208.
#    > Found 1 clusters in hypercube 209.
#    > Found 2 clusters in hypercube 210.
#    > Found 0 clusters in hypercube 211.
# Cube_212 is empty.
#
# Cube_213 is empty.
#
# Cube_214 is empty.
#
#    > Found 1 clusters in hypercube 215.
#    > Found 1 clusters in hypercube 216.
#    > Found 0 clusters in hypercube 217.
# Cube_218 is empty.
#
# Cube_219 is empty.
#
# Cube_220 is empty.
#
# Cube_221 is empty.
#
# Cube_222 is empty.
#
# Cube_223 is empty.
#
# Cube_224 is empty.
#
# Cube_225 is empty.
#
#    > Found 0 clusters in hypercube 226.
# Cube_227 is empty.
#
# Cube_228 is empty.
#
# Cube_229 is empty.
#
# Cube_230 is empty.
#
#    > Found 1 clusters in hypercube 231.
#    > Found 2 clusters in hypercube 232.
#    > Found 0 clusters in hypercube 233.
# Cube_234 is empty.
#
# Cube_235 is empty.
#
# Cube_236 is empty.
#
#    > Found 2 clusters in hypercube 237.
#    > Found 2 clusters in hypercube 238.
#    > Found 1 clusters in hypercube 239.
#    > Found 2 clusters in hypercube 240.
#    > Found 0 clusters in hypercube 241.
# Cube_242 is empty.
#
#    > Found 1 clusters in hypercube 243.
#    > Found 2 clusters in hypercube 244.
#    > Found 1 clusters in hypercube 245.
#    > Found 1 clusters in hypercube 246.
#    > Found 0 clusters in hypercube 247.
# Cube_248 is empty.
#
#    > Found 1 clusters in hypercube 249.
#    > Found 3 clusters in hypercube 250.
#    > Found 2 clusters in hypercube 251.
#    > Found 1 clusters in hypercube 252.
# Cube_253 is empty.
#
#    > Found 2 clusters in hypercube 254.
#    > Found 1 clusters in hypercube 255.
#    > Found 0 clusters in hypercube 256.
#    > Found 0 clusters in hypercube 257.
# Cube_258 is empty.
#
# Cube_259 is empty.
#
#    > Found 0 clusters in hypercube 260.
# Cube_261 is empty.
#
# Cube_262 is empty.
#
# Cube_263 is empty.
#
# Cube_264 is empty.
#
# Cube_265 is empty.
#
# Cube_266 is empty.
#
# Cube_267 is empty.
#
# Cube_268 is empty.
#
# Cube_269 is empty.
#
# Cube_270 is empty.
#
# Cube_271 is empty.
#
# Cube_272 is empty.
#
# Cube_273 is empty.
#
#    > Found 1 clusters in hypercube 274.
# Cube_275 is empty.
#
# Cube_276 is empty.
#
#    > Found 1 clusters in hypercube 277.
# Cube_278 is empty.
#
# Cube_279 is empty.
#
# Cube_280 is empty.
#
# Cube_281 is empty.
#
# Cube_282 is empty.
#
# Cube_283 is empty.
#
# Cube_284 is empty.
#
# Cube_285 is empty.
#
# Cube_286 is empty.
#
# Cube_287 is empty.
#
# Cube_288 is empty.
#
# Cube_289 is empty.
#
# Cube_290 is empty.
#
# Cube_291 is empty.
#
# Cube_292 is empty.
#
# Cube_293 is empty.
#
#    > Found 1 clusters in hypercube 294.
#    > Found 1 clusters in hypercube 295.
# Cube_296 is empty.
#
# Cube_297 is empty.
#
# Cube_298 is empty.
#
# Cube_299 is empty.
#
# Cube_300 is empty.
#
# Cube_301 is empty.
#
#    > Found 0 clusters in hypercube 302.
#    > Found 1 clusters in hypercube 303.
# Cube_304 is empty.
#
# Cube_305 is empty.
#
# Cube_306 is empty.
#
# Cube_307 is empty.
#
#    > Found 0 clusters in hypercube 308.
#    > Found 1 clusters in hypercube 309.
#    > Found 1 clusters in hypercube 310.
#    > Found 1 clusters in hypercube 311.
# Cube_312 is empty.
#
#    > Found 0 clusters in hypercube 313.
#    > Found 1 clusters in hypercube 314.
#    > Found 2 clusters in hypercube 315.
#    > Found 0 clusters in hypercube 316.
# Cube_317 is empty.
#
# Cube_318 is empty.
#
# Cube_319 is empty.
#
#    > Found 2 clusters in hypercube 320.
#    > Found 2 clusters in hypercube 321.
#    > Found 2 clusters in hypercube 322.
#    > Found 2 clusters in hypercube 323.
# Cube_324 is empty.
#
# Cube_325 is empty.
#
#    > Found 0 clusters in hypercube 326.
#    > Found 1 clusters in hypercube 327.
#    > Found 2 clusters in hypercube 328.
#    > Found 1 clusters in hypercube 329.
# Cube_330 is empty.
#
#    > Found 0 clusters in hypercube 331.
# Cube_332 is empty.
#
#    > Found 0 clusters in hypercube 333.
#    > Found 1 clusters in hypercube 334.
#    > Found 1 clusters in hypercube 335.
# Cube_336 is empty.
#
# Cube_337 is empty.
#
# Cube_338 is empty.
#
# Cube_339 is empty.
#
# Cube_340 is empty.
#
# Cube_341 is empty.
#
# Cube_342 is empty.
#
#    > Found 0 clusters in hypercube 343.
#    > Found 2 clusters in hypercube 344.
#    > Found 1 clusters in hypercube 345.
# Cube_346 is empty.
#
# Cube_347 is empty.
#
#    > Found 0 clusters in hypercube 348.
#    > Found 0 clusters in hypercube 349.
#    > Found 2 clusters in hypercube 350.
#    > Found 0 clusters in hypercube 351.
# Cube_352 is empty.
#
# Cube_353 is empty.
#
#    > Found 0 clusters in hypercube 354.
#    > Found 1 clusters in hypercube 355.
#    > Found 1 clusters in hypercube 356.
#    > Found 1 clusters in hypercube 357.
# Cube_358 is empty.
#
# Cube_359 is empty.
#
# Cube_360 is empty.
#
#    > Found 2 clusters in hypercube 361.
#    > Found 2 clusters in hypercube 362.
#    > Found 1 clusters in hypercube 363.
#    > Found 1 clusters in hypercube 364.
# Cube_365 is empty.
#
# Cube_366 is empty.
#
# Cube_367 is empty.
#
#    > Found 1 clusters in hypercube 368.
#    > Found 1 clusters in hypercube 369.
#    > Found 2 clusters in hypercube 370.
#    > Found 2 clusters in hypercube 371.
# Cube_372 is empty.
#
#    > Found 0 clusters in hypercube 373.
#    > Found 0 clusters in hypercube 374.
#    > Found 0 clusters in hypercube 375.
#    > Found 2 clusters in hypercube 376.
#    > Found 1 clusters in hypercube 377.
# Cube_378 is empty.
#
# Cube_379 is empty.
#
# Cube_380 is empty.
#
# Cube_381 is empty.
#
# Cube_382 is empty.
#
# Cube_383 is empty.
#
# Cube_384 is empty.
#
# Cube_385 is empty.
#
# Cube_386 is empty.
#
# Cube_387 is empty.
#
# Cube_388 is empty.
#
# Cube_389 is empty.
#
# Cube_390 is empty.
#
# Cube_391 is empty.
#
# Cube_392 is empty.
#
# Cube_393 is empty.
#
# Cube_394 is empty.
#
# Cube_395 is empty.
#
# Cube_396 is empty.
#
# Cube_397 is empty.
#
# Cube_398 is empty.
#
# Cube_399 is empty.
#
# Cube_400 is empty.
#
#    > Found 1 clusters in hypercube 401.
#    > Found 1 clusters in hypercube 402.
# Cube_403 is empty.
#
# Cube_404 is empty.
#
# Cube_405 is empty.
#
# Cube_406 is empty.
#
#    > Found 2 clusters in hypercube 407.
#    > Found 1 clusters in hypercube 408.
#    > Found 0 clusters in hypercube 409.
#    > Found 1 clusters in hypercube 410.
# Cube_411 is empty.
#
# Cube_412 is empty.
#
#    > Found 1 clusters in hypercube 413.
#    > Found 1 clusters in hypercube 414.
#    > Found 2 clusters in hypercube 415.
#    > Found 2 clusters in hypercube 416.
# Cube_417 is empty.
#
#    > Found 2 clusters in hypercube 418.
#    > Found 2 clusters in hypercube 419.
#    > Found 1 clusters in hypercube 420.
#    > Found 0 clusters in hypercube 421.
# Cube_422 is empty.
#
#    > Found 2 clusters in hypercube 423.
#    > Found 1 clusters in hypercube 424.
#    > Found 0 clusters in hypercube 425.
# Cube_426 is empty.
#
# Cube_427 is empty.
#
# Cube_428 is empty.
#
# Cube_429 is empty.
#
# Cube_430 is empty.
#
# Cube_431 is empty.
#
# Cube_432 is empty.
#
# Cube_433 is empty.
#
# Cube_434 is empty.
#
# Cube_435 is empty.
#
# Cube_436 is empty.
#
# Cube_437 is empty.
#
# Cube_438 is empty.
#
# Cube_439 is empty.
#
#    > Found 0 clusters in hypercube 440.
# Cube_441 is empty.
#
# Cube_442 is empty.
#
#    > Found 0 clusters in hypercube 443.
# Cube_444 is empty.
#
# Cube_445 is empty.
#
#    > Found 0 clusters in hypercube 446.
#    > Found 1 clusters in hypercube 447.
#    > Found 1 clusters in hypercube 448.
#    > Found 2 clusters in hypercube 449.
#    > Found 0 clusters in hypercube 450.
# Cube_451 is empty.
#
# Cube_452 is empty.
#
# Cube_453 is empty.
#
# Cube_454 is empty.
#
#    > Found 1 clusters in hypercube 455.
#    > Found 1 clusters in hypercube 456.
#    > Found 2 clusters in hypercube 457.
#    > Found 1 clusters in hypercube 458.
#    > Found 0 clusters in hypercube 459.
# Cube_460 is empty.
#
# Cube_461 is empty.
#
# Cube_462 is empty.
#
#    > Found 0 clusters in hypercube 463.
#    > Found 3 clusters in hypercube 464.
#    > Found 1 clusters in hypercube 465.
#    > Found 1 clusters in hypercube 466.
# Cube_467 is empty.
#
# Cube_468 is empty.
#
#    > Found 0 clusters in hypercube 469.
#    > Found 1 clusters in hypercube 470.
#    > Found 3 clusters in hypercube 471.
#    > Found 1 clusters in hypercube 472.
#    > Found 0 clusters in hypercube 473.
# Cube_474 is empty.
#
# Cube_475 is empty.
#
# Cube_476 is empty.
#
#    > Found 0 clusters in hypercube 477.
#    > Found 0 clusters in hypercube 478.
# Cube_479 is empty.
#
# Cube_480 is empty.
#
# Cube_481 is empty.
#
# Cube_482 is empty.
#
# Cube_483 is empty.
#
# Cube_484 is empty.
#
# Cube_485 is empty.
#
# Cube_486 is empty.
#
# Cube_487 is empty.
#
# Cube_488 is empty.
#
# Cube_489 is empty.
#
# Cube_490 is empty.
#
# Cube_491 is empty.
#
# Cube_492 is empty.
#
# Cube_493 is empty.
#
# Cube_494 is empty.
#
# Cube_495 is empty.
#
# Cube_496 is empty.
#
# Cube_497 is empty.
#
#    > Found 1 clusters in hypercube 498.
# Cube_499 is empty.
#
# Cube_500 is empty.
#
# Cube_501 is empty.
#
#    > Found 1 clusters in hypercube 502.
# Cube_503 is empty.
#
# Cube_504 is empty.
#
# Cube_505 is empty.
#
# Cube_506 is empty.
#
# Cube_507 is empty.
#
# Cube_508 is empty.
#
# Cube_509 is empty.
#
# Cube_510 is empty.
#
# Cube_511 is empty.
#
# Cube_512 is empty.
#
# Cube_513 is empty.
#
# Cube_514 is empty.
#
# Cube_515 is empty.
#
# Cube_516 is empty.
#
#    > Found 1 clusters in hypercube 517.
# Cube_518 is empty.
#
#    > Found 1 clusters in hypercube 519.
# Cube_520 is empty.
#
# Cube_521 is empty.
#
# Cube_522 is empty.
#
#    > Found 1 clusters in hypercube 523.
#    > Found 1 clusters in hypercube 524.
#    > Found 1 clusters in hypercube 525.
# Cube_526 is empty.
#
# Cube_527 is empty.
#
# Cube_528 is empty.
#
#    > Found 1 clusters in hypercube 529.
#    > Found 2 clusters in hypercube 530.
#    > Found 1 clusters in hypercube 531.
#    > Found 1 clusters in hypercube 532.
# Cube_533 is empty.
#
# Cube_534 is empty.
#
# Cube_535 is empty.
#
#    > Found 1 clusters in hypercube 536.
#    > Found 2 clusters in hypercube 537.
#    > Found 2 clusters in hypercube 538.
#    > Found 2 clusters in hypercube 539.
#    > Found 0 clusters in hypercube 540.
#    > Found 1 clusters in hypercube 541.
#    > Found 2 clusters in hypercube 542.
#    > Found 1 clusters in hypercube 543.
#    > Found 0 clusters in hypercube 544.
# Cube_545 is empty.
#
# Cube_546 is empty.
#
# Cube_547 is empty.
#
# Cube_548 is empty.
#
# Cube_549 is empty.
#
# Cube_550 is empty.
#
# Cube_551 is empty.
#
# Cube_552 is empty.
#
# Cube_553 is empty.
#
# Cube_554 is empty.
#
# Cube_555 is empty.
#
# Cube_556 is empty.
#
#    > Found 1 clusters in hypercube 557.
# Cube_558 is empty.
#
#    > Found 1 clusters in hypercube 559.
# Cube_560 is empty.
#
# Cube_561 is empty.
#
# Cube_562 is empty.
#
#    > Found 1 clusters in hypercube 563.
#    > Found 1 clusters in hypercube 564.
#    > Found 2 clusters in hypercube 565.
# Cube_566 is empty.
#
# Cube_567 is empty.
#
# Cube_568 is empty.
#
#    > Found 1 clusters in hypercube 569.
#    > Found 2 clusters in hypercube 570.
#    > Found 1 clusters in hypercube 571.
# Cube_572 is empty.
#
# Cube_573 is empty.
#
# Cube_574 is empty.
#
# Cube_575 is empty.
#
#    > Found 0 clusters in hypercube 576.
#    > Found 2 clusters in hypercube 577.
#    > Found 2 clusters in hypercube 578.
#    > Found 1 clusters in hypercube 579.
#    > Found 1 clusters in hypercube 580.
#    > Found 0 clusters in hypercube 581.
# Cube_582 is empty.
#
#    > Found 2 clusters in hypercube 583.
#    > Found 2 clusters in hypercube 584.
#    > Found 1 clusters in hypercube 585.
#    > Found 0 clusters in hypercube 586.
# Cube_587 is empty.
#
#    > Found 0 clusters in hypercube 588.
#    > Found 0 clusters in hypercube 589.
#    > Found 0 clusters in hypercube 590.
# Cube_591 is empty.
#
# Cube_592 is empty.
#
# Cube_593 is empty.
#
# Cube_594 is empty.
#
# Cube_595 is empty.
#
# Cube_596 is empty.
#
# Cube_597 is empty.
#
# Cube_598 is empty.
#
# Cube_599 is empty.
#
#    > Found 0 clusters in hypercube 600.
# Cube_601 is empty.
#
# Cube_602 is empty.
#
# Cube_603 is empty.
#
#    > Found 0 clusters in hypercube 604.
#    > Found 2 clusters in hypercube 605.
#    > Found 1 clusters in hypercube 606.
# Cube_607 is empty.
#
# Cube_608 is empty.
#
# Cube_609 is empty.
#
# Cube_610 is empty.
#
# Cube_611 is empty.
#
# Cube_612 is empty.
#
#    > Found 0 clusters in hypercube 613.
#    > Found 2 clusters in hypercube 614.
#    > Found 1 clusters in hypercube 615.
# Cube_616 is empty.
#
# Cube_617 is empty.
#
# Cube_618 is empty.
#
# Cube_619 is empty.
#
#    > Found 0 clusters in hypercube 620.
#    > Found 1 clusters in hypercube 621.
#    > Found 2 clusters in hypercube 622.
#    > Found 1 clusters in hypercube 623.
# Cube_624 is empty.
#
# Cube_625 is empty.
#
# Cube_626 is empty.
#
# Cube_627 is empty.
#
# Cube_628 is empty.
#
#    > Found 1 clusters in hypercube 629.
# Cube_630 is empty.
#
# Cube_631 is empty.
#
# Cube_632 is empty.
#
# Cube_633 is empty.
#
# Cube_634 is empty.
#
# Cube_635 is empty.
#
# Cube_636 is empty.
#
# Cube_637 is empty.
#
# Cube_638 is empty.
#
# Cube_639 is empty.
#
# Cube_640 is empty.
#
# Cube_641 is empty.
#
# Cube_642 is empty.
#
# Cube_643 is empty.
#
# Cube_644 is empty.
#
# Cube_645 is empty.
#
# Cube_646 is empty.
#
# Cube_647 is empty.
#
# Cube_648 is empty.
#
#    > Found 0 clusters in hypercube 649.
# Cube_650 is empty.
#
#    > Found 0 clusters in hypercube 651.
#    > Found 1 clusters in hypercube 652.
#    > Found 2 clusters in hypercube 653.
#    > Found 1 clusters in hypercube 654.
# Cube_655 is empty.
#
# Cube_656 is empty.
#
# Cube_657 is empty.
#
# Cube_658 is empty.
#
#    > Found 0 clusters in hypercube 659.
#    > Found 1 clusters in hypercube 660.
#    > Found 2 clusters in hypercube 661.
#    > Found 0 clusters in hypercube 662.
# Cube_663 is empty.
#
# Cube_664 is empty.
#
# Cube_665 is empty.
#
# Cube_666 is empty.
#
#    > Found 1 clusters in hypercube 667.
#    > Found 3 clusters in hypercube 668.
#    > Found 2 clusters in hypercube 669.
#    > Found 1 clusters in hypercube 670.
# Cube_671 is empty.
#
#    > Found 0 clusters in hypercube 672.
#    > Found 1 clusters in hypercube 673.
#    > Found 0 clusters in hypercube 674.
#    > Found 1 clusters in hypercube 675.
# Cube_676 is empty.
#
# Cube_677 is empty.
#
# Cube_678 is empty.
#
# Cube_679 is empty.
#
#    > Found 0 clusters in hypercube 680.
#    > Found 0 clusters in hypercube 681.
# Cube_682 is empty.
#
# Cube_683 is empty.
#
# Cube_684 is empty.
#
# Cube_685 is empty.
#
# Cube_686 is empty.
#
# Cube_687 is empty.
#
# Cube_688 is empty.
#
# Cube_689 is empty.
#
# Cube_690 is empty.
#
# Cube_691 is empty.
#
#    > Found 2 clusters in hypercube 692.
#    > Found 1 clusters in hypercube 693.
#    > Found 1 clusters in hypercube 694.
# Cube_695 is empty.
#
# Cube_696 is empty.
#
#    > Found 1 clusters in hypercube 697.
#    > Found 2 clusters in hypercube 698.
#    > Found 1 clusters in hypercube 699.
#    > Found 0 clusters in hypercube 700.
# Cube_701 is empty.
#
# Cube_702 is empty.
#
#    > Found 1 clusters in hypercube 703.
#    > Found 1 clusters in hypercube 704.
#    > Found 2 clusters in hypercube 705.
#    > Found 1 clusters in hypercube 706.
# Cube_707 is empty.
#
# Cube_708 is empty.
#
#    > Found 2 clusters in hypercube 709.
#    > Found 1 clusters in hypercube 710.
#    > Found 1 clusters in hypercube 711.
#    > Found 3 clusters in hypercube 712.
#    > Found 1 clusters in hypercube 713.
#    > Found 2 clusters in hypercube 714.
#    > Found 1 clusters in hypercube 715.
#    > Found 1 clusters in hypercube 716.
#    > Found 0 clusters in hypercube 717.
#    > Found 2 clusters in hypercube 718.
#    > Found 2 clusters in hypercube 719.
# Cube_720 is empty.
#
# Cube_721 is empty.
#
# Cube_722 is empty.
#
# Cube_723 is empty.
#
# Cube_724 is empty.
#
#    > Found 1 clusters in hypercube 725.
#    > Found 1 clusters in hypercube 726.
# Cube_727 is empty.
#
# Cube_728 is empty.
#
# Cube_729 is empty.
#
# Cube_730 is empty.
#
# Cube_731 is empty.
#
#    > Found 1 clusters in hypercube 732.
# Cube_733 is empty.
#
# Cube_734 is empty.
#
# Cube_735 is empty.
#
# Cube_736 is empty.
#
# Cube_737 is empty.
#
# Cube_738 is empty.
#
#    > Found 1 clusters in hypercube 739.
# Cube_740 is empty.
#
# Cube_741 is empty.
#
# Cube_742 is empty.
#
# Cube_743 is empty.
#
# Cube_744 is empty.
#
# Cube_745 is empty.
#
# Cube_746 is empty.
#
# Cube_747 is empty.
#
# Cube_748 is empty.
#
# Cube_749 is empty.
#
# Cube_750 is empty.
#
# Cube_751 is empty.
#
# Cube_752 is empty.
#
# Cube_753 is empty.
#
# Cube_754 is empty.
#
#    > Found 0 clusters in hypercube 755.
# Cube_756 is empty.
#
# Cube_757 is empty.
#
#    > Found 0 clusters in hypercube 758.
#    > Found 1 clusters in hypercube 759.
#    > Found 2 clusters in hypercube 760.
#    > Found 1 clusters in hypercube 761.
# Cube_762 is empty.
#
#    > Found 1 clusters in hypercube 763.
#    > Found 2 clusters in hypercube 764.
#    > Found 1 clusters in hypercube 765.
#    > Found 1 clusters in hypercube 766.
# Cube_767 is empty.
#
#    > Found 0 clusters in hypercube 768.
#    > Found 1 clusters in hypercube 769.
#    > Found 2 clusters in hypercube 770.
#    > Found 1 clusters in hypercube 771.
#    > Found 2 clusters in hypercube 772.
#    > Found 1 clusters in hypercube 773.
# Cube_774 is empty.
#
#    > Found 1 clusters in hypercube 775.
#    > Found 2 clusters in hypercube 776.
#    > Found 0 clusters in hypercube 777.
# Cube_778 is empty.
#
# Cube_779 is empty.
#
# Cube_780 is empty.
#
# Cube_781 is empty.
#
#    > Found 0 clusters in hypercube 782.
#    > Found 1 clusters in hypercube 783.
# Cube_784 is empty.
#
# Cube_785 is empty.
#
# Cube_786 is empty.
#
# Cube_787 is empty.
#
# Cube_788 is empty.
#
# Cube_789 is empty.
#
# Cube_790 is empty.
#
# Cube_791 is empty.
#
# Cube_792 is empty.
#
# Cube_793 is empty.
#
#    > Found 1 clusters in hypercube 794.
#    > Found 1 clusters in hypercube 795.
#    > Found 0 clusters in hypercube 796.
#    > Found 0 clusters in hypercube 797.
# Cube_798 is empty.
#
# Cube_799 is empty.
#
#    > Found 2 clusters in hypercube 800.
#    > Found 2 clusters in hypercube 801.
#    > Found 2 clusters in hypercube 802.
#    > Found 1 clusters in hypercube 803.
# Cube_804 is empty.
#
#    > Found 0 clusters in hypercube 805.
#    > Found 2 clusters in hypercube 806.
#    > Found 2 clusters in hypercube 807.
#    > Found 2 clusters in hypercube 808.
#    > Found 1 clusters in hypercube 809.
# Cube_810 is empty.
#
# Cube_811 is empty.
#
#    > Found 0 clusters in hypercube 812.
#    > Found 2 clusters in hypercube 813.
#    > Found 2 clusters in hypercube 814.
#    > Found 1 clusters in hypercube 815.
#    > Found 1 clusters in hypercube 816.
# Cube_817 is empty.
#
# Cube_818 is empty.
#
#    > Found 2 clusters in hypercube 819.
#    > Found 2 clusters in hypercube 820.
#    > Found 1 clusters in hypercube 821.
# Cube_822 is empty.
#
# Cube_823 is empty.
#
# Cube_824 is empty.
#
# Cube_825 is empty.
#
# Cube_826 is empty.
#
#    > Found 0 clusters in hypercube 827.
#    > Found 0 clusters in hypercube 828.
# Cube_829 is empty.
#
# Cube_830 is empty.
#
# Cube_831 is empty.
#
#    > Found 1 clusters in hypercube 832.
# Cube_833 is empty.
#
# Cube_834 is empty.
#
# Cube_835 is empty.
#
# Cube_836 is empty.
#
# Cube_837 is empty.
#
# Cube_838 is empty.
#
# Cube_839 is empty.
#
# Cube_840 is empty.
#
# Cube_841 is empty.
#
#    > Found 0 clusters in hypercube 842.
# Cube_843 is empty.
#
# Cube_844 is empty.
#
#    > Found 0 clusters in hypercube 845.
# Cube_846 is empty.
#
#    > Found 0 clusters in hypercube 847.
#    > Found 1 clusters in hypercube 848.
#    > Found 0 clusters in hypercube 849.
#    > Found 0 clusters in hypercube 850.
# Cube_851 is empty.
#
# Cube_852 is empty.
#
#    > Found 1 clusters in hypercube 853.
#    > Found 3 clusters in hypercube 854.
#    > Found 2 clusters in hypercube 855.
#    > Found 1 clusters in hypercube 856.
# Cube_857 is empty.
#
#    > Found 1 clusters in hypercube 858.
#    > Found 3 clusters in hypercube 859.
#    > Found 1 clusters in hypercube 860.
#    > Found 1 clusters in hypercube 861.
# Cube_862 is empty.
#
# Cube_863 is empty.
#
#    > Found 1 clusters in hypercube 864.
#    > Found 1 clusters in hypercube 865.
#    > Found 2 clusters in hypercube 866.
#    > Found 2 clusters in hypercube 867.
#    > Found 1 clusters in hypercube 868.
# Cube_869 is empty.
#
# Cube_870 is empty.
#
#    > Found 0 clusters in hypercube 871.
#    > Found 1 clusters in hypercube 872.
#    > Found 1 clusters in hypercube 873.
# Cube_874 is empty.
#
#    > Found 0 clusters in hypercube 875.
# Cube_876 is empty.
#
# Cube_877 is empty.
#
# Cube_878 is empty.
#
# Cube_879 is empty.
#
# Cube_880 is empty.
#
# Cube_881 is empty.
#
# Cube_882 is empty.
#
# Cube_883 is empty.
#
# Cube_884 is empty.
#
# Cube_885 is empty.
#
# Cube_886 is empty.
#
# Cube_887 is empty.
#
#    > Found 0 clusters in hypercube 888.
#    > Found 0 clusters in hypercube 889.
#    > Found 0 clusters in hypercube 890.
#    > Found 0 clusters in hypercube 891.
# Cube_892 is empty.
#
#    > Found 0 clusters in hypercube 893.
#    > Found 2 clusters in hypercube 894.
#    > Found 1 clusters in hypercube 895.
#    > Found 1 clusters in hypercube 896.
#    > Found 2 clusters in hypercube 897.
#    > Found 1 clusters in hypercube 898.
# Cube_899 is empty.
#
#    > Found 1 clusters in hypercube 900.
#    > Found 1 clusters in hypercube 901.
#    > Found 2 clusters in hypercube 902.
#    > Found 1 clusters in hypercube 903.
#    > Found 1 clusters in hypercube 904.
# Cube_905 is empty.
#
# Cube_906 is empty.
#
#    > Found 1 clusters in hypercube 907.
#    > Found 3 clusters in hypercube 908.
#    > Found 1 clusters in hypercube 909.
#    > Found 1 clusters in hypercube 910.
#    > Found 1 clusters in hypercube 911.
# Cube_912 is empty.
#
# Cube_913 is empty.
#
#    > Found 0 clusters in hypercube 914.
#    > Found 3 clusters in hypercube 915.
#    > Found 0 clusters in hypercube 916.
#    > Found 1 clusters in hypercube 917.
# Cube_918 is empty.
#
# Cube_919 is empty.
#
# Cube_920 is empty.
#
#    > Found 0 clusters in hypercube 921.
# Cube_922 is empty.
#
# Cube_923 is empty.
#
# Cube_924 is empty.
#
# Cube_925 is empty.
#
# Cube_926 is empty.
#
# Cube_927 is empty.
#
# Cube_928 is empty.
#
# Cube_929 is empty.
#
#    > Found 0 clusters in hypercube 930.
#    > Found 1 clusters in hypercube 931.
#    > Found 1 clusters in hypercube 932.
#    > Found 0 clusters in hypercube 933.
# Cube_934 is empty.
#
# Cube_935 is empty.
#
#    > Found 2 clusters in hypercube 936.
#    > Found 2 clusters in hypercube 937.
#    > Found 2 clusters in hypercube 938.
#    > Found 1 clusters in hypercube 939.
#    > Found 0 clusters in hypercube 940.
#    > Found 2 clusters in hypercube 941.
#    > Found 2 clusters in hypercube 942.
#    > Found 2 clusters in hypercube 943.
#    > Found 1 clusters in hypercube 944.
# Cube_945 is empty.
#
# Cube_946 is empty.
#
# Cube_947 is empty.
#
#    > Found 1 clusters in hypercube 948.
#    > Found 1 clusters in hypercube 949.
#    > Found 1 clusters in hypercube 950.
#    > Found 0 clusters in hypercube 951.
# Cube_952 is empty.
#
#    > Found 0 clusters in hypercube 953.
#    > Found 1 clusters in hypercube 954.
#    > Found 1 clusters in hypercube 955.
#    > Found 1 clusters in hypercube 956.
# Cube_957 is empty.
#
#    > Found 0 clusters in hypercube 958.
# Cube_959 is empty.
#
# Cube_960 is empty.
#
#    > Found 0 clusters in hypercube 961.
#    > Found 0 clusters in hypercube 962.
#    > Found 0 clusters in hypercube 963.
# Cube_964 is empty.
#
#    > Found 0 clusters in hypercube 965.
# Cube_966 is empty.
#
# Cube_967 is empty.
#
# Cube_968 is empty.
#
# Cube_969 is empty.
#
# Cube_970 is empty.
#
# Cube_971 is empty.
#
# Cube_972 is empty.
#
# Cube_973 is empty.
#
#    > Found 1 clusters in hypercube 974.
#    > Found 1 clusters in hypercube 975.
#    > Found 0 clusters in hypercube 976.
# Cube_977 is empty.
#
# Cube_978 is empty.
#
# Cube_979 is empty.
#
#    > Found 2 clusters in hypercube 980.
#    > Found 2 clusters in hypercube 981.
#    > Found 1 clusters in hypercube 982.
#    > Found 1 clusters in hypercube 983.
#    > Found 0 clusters in hypercube 984.
# Cube_985 is empty.
#
#    > Found 2 clusters in hypercube 986.
#    > Found 2 clusters in hypercube 987.
#    > Found 2 clusters in hypercube 988.
#    > Found 1 clusters in hypercube 989.
#    > Found 0 clusters in hypercube 990.
# Cube_991 is empty.
#
#    > Found 1 clusters in hypercube 992.
#    > Found 2 clusters in hypercube 993.
#    > Found 2 clusters in hypercube 994.
#    > Found 1 clusters in hypercube 995.
#    > Found 0 clusters in hypercube 996.
# Cube_997 is empty.
#
#    > Found 0 clusters in hypercube 998.
#    > Found 1 clusters in hypercube 999.
#    > Found 2 clusters in hypercube 1000.
#    > Found 1 clusters in hypercube 1001.
#    > Found 0 clusters in hypercube 1002.
# Cube_1003 is empty.
#
# Cube_1004 is empty.
#
# Cube_1005 is empty.
#
# Cube_1006 is empty.
#
# Cube_1007 is empty.
#
#    > Found 0 clusters in hypercube 1008.
#    > Found 0 clusters in hypercube 1009.
# Cube_1010 is empty.
#
# Cube_1011 is empty.
#
#    > Found 0 clusters in hypercube 1012.
# Cube_1013 is empty.
#
# Cube_1014 is empty.
#
# Cube_1015 is empty.
#
# Cube_1016 is empty.
#
# Cube_1017 is empty.
#
# Cube_1018 is empty.
#
# Cube_1019 is empty.
#
#    > Found 1 clusters in hypercube 1020.
#    > Found 1 clusters in hypercube 1021.
#    > Found 1 clusters in hypercube 1022.
#    > Found 1 clusters in hypercube 1023.
# Cube_1024 is empty.
#
#    > Found 1 clusters in hypercube 1025.
# Cube_1026 is empty.
#
# Cube_1027 is empty.
#
# Cube_1028 is empty.
#
# Cube_1029 is empty.
#
# Cube_1030 is empty.
#
# Cube_1031 is empty.
#
# Cube_1032 is empty.
#
# Cube_1033 is empty.
#
# Cube_1034 is empty.
#
# Cube_1035 is empty.
#
# Cube_1036 is empty.
#
# Cube_1037 is empty.
#
# Cube_1038 is empty.
#
# Cube_1039 is empty.
#
# Cube_1040 is empty.
#
# Cube_1041 is empty.
#
#    > Found 2 clusters in hypercube 1042.
#    > Found 2 clusters in hypercube 1043.
#    > Found 1 clusters in hypercube 1044.
# Cube_1045 is empty.
#
# Cube_1046 is empty.
#
#    > Found 1 clusters in hypercube 1047.
#    > Found 2 clusters in hypercube 1048.
#    > Found 2 clusters in hypercube 1049.
#    > Found 1 clusters in hypercube 1050.
# Cube_1051 is empty.
#
# Cube_1052 is empty.
#
#    > Found 1 clusters in hypercube 1053.
#    > Found 2 clusters in hypercube 1054.
#    > Found 1 clusters in hypercube 1055.
#    > Found 1 clusters in hypercube 1056.
# Cube_1057 is empty.
#
#    > Found 1 clusters in hypercube 1058.
#    > Found 3 clusters in hypercube 1059.
#    > Found 1 clusters in hypercube 1060.
#    > Found 2 clusters in hypercube 1061.
#    > Found 1 clusters in hypercube 1062.
#    > Found 2 clusters in hypercube 1063.
#    > Found 1 clusters in hypercube 1064.
# Cube_1065 is empty.
#
#    > Found 1 clusters in hypercube 1066.
#    > Found 0 clusters in hypercube 1067.
# Cube_1068 is empty.
#
#    > Found 0 clusters in hypercube 1069.
#    > Found 0 clusters in hypercube 1070.
# Cube_1071 is empty.
#
# Cube_1072 is empty.
#
# Cube_1073 is empty.
#
# Cube_1074 is empty.
#
# Cube_1075 is empty.
#
# Cube_1076 is empty.
#
# Cube_1077 is empty.
#
# Cube_1078 is empty.
#
#    > Found 1 clusters in hypercube 1079.
#    > Found 1 clusters in hypercube 1080.
#    > Found 1 clusters in hypercube 1081.
#    > Found 0 clusters in hypercube 1082.
# Cube_1083 is empty.
#
#    > Found 1 clusters in hypercube 1084.
#    > Found 1 clusters in hypercube 1085.
#    > Found 2 clusters in hypercube 1086.
#    > Found 1 clusters in hypercube 1087.
# Cube_1088 is empty.
#
# Cube_1089 is empty.
#
#    > Found 1 clusters in hypercube 1090.
#    > Found 2 clusters in hypercube 1091.
#    > Found 1 clusters in hypercube 1092.
#    > Found 1 clusters in hypercube 1093.
# Cube_1094 is empty.
#
# Cube_1095 is empty.
#
#    > Found 2 clusters in hypercube 1096.
#    > Found 2 clusters in hypercube 1097.
#    > Found 0 clusters in hypercube 1098.
#    > Found 2 clusters in hypercube 1099.
# Cube_1100 is empty.
#
# Cube_1101 is empty.
#
# Cube_1102 is empty.
#
#    > Found 0 clusters in hypercube 1103.
#    > Found 1 clusters in hypercube 1104.
#    > Found 0 clusters in hypercube 1105.
# Cube_1106 is empty.
#
# Cube_1107 is empty.
#
# Cube_1108 is empty.
#
# Cube_1109 is empty.
#
# Cube_1110 is empty.
#
# Cube_1111 is empty.
#
# Cube_1112 is empty.
#
# Cube_1113 is empty.
#
# Cube_1114 is empty.
#
# Cube_1115 is empty.
#
#    > Found 0 clusters in hypercube 1116.
# Cube_1117 is empty.
#
# Cube_1118 is empty.
#
# Cube_1119 is empty.
#
# Cube_1120 is empty.
#
#    > Found 1 clusters in hypercube 1121.
#    > Found 2 clusters in hypercube 1122.
#    > Found 2 clusters in hypercube 1123.
#    > Found 1 clusters in hypercube 1124.
# Cube_1125 is empty.
#
# Cube_1126 is empty.
#
# Cube_1127 is empty.
#
#    > Found 2 clusters in hypercube 1128.
#    > Found 2 clusters in hypercube 1129.
#    > Found 2 clusters in hypercube 1130.
#    > Found 1 clusters in hypercube 1131.
# Cube_1132 is empty.
#
#    > Found 1 clusters in hypercube 1133.
#    > Found 1 clusters in hypercube 1134.
#    > Found 2 clusters in hypercube 1135.
#    > Found 2 clusters in hypercube 1136.
#    > Found 1 clusters in hypercube 1137.
#    > Found 0 clusters in hypercube 1138.
#    > Found 2 clusters in hypercube 1139.
#    > Found 2 clusters in hypercube 1140.
#    > Found 1 clusters in hypercube 1141.
#    > Found 3 clusters in hypercube 1142.
# Cube_1143 is empty.
#
# Cube_1144 is empty.
#
#    > Found 1 clusters in hypercube 1145.
#    > Found 1 clusters in hypercube 1146.
#    > Found 1 clusters in hypercube 1147.
#    > Found 0 clusters in hypercube 1148.
# Cube_1149 is empty.
#
# Cube_1150 is empty.
#
# Cube_1151 is empty.
#
# Cube_1152 is empty.
#
# Cube_1153 is empty.
#
# Cube_1154 is empty.
#
# Cube_1155 is empty.
#
# Cube_1156 is empty.
#
# Cube_1157 is empty.
#
# Cube_1158 is empty.
#
# Cube_1159 is empty.
#
# Cube_1160 is empty.
#
# Cube_1161 is empty.
#
# Cube_1162 is empty.
#
#    > Found 1 clusters in hypercube 1163.
# Cube_1164 is empty.
#
#    > Found 0 clusters in hypercube 1165.
#    > Found 1 clusters in hypercube 1166.
#    > Found 1 clusters in hypercube 1167.
#    > Found 0 clusters in hypercube 1168.
# Cube_1169 is empty.
#
#    > Found 1 clusters in hypercube 1170.
#    > Found 1 clusters in hypercube 1171.
#    > Found 1 clusters in hypercube 1172.
#    > Found 0 clusters in hypercube 1173.
#    > Found 0 clusters in hypercube 1174.
#    > Found 2 clusters in hypercube 1175.
#    > Found 1 clusters in hypercube 1176.
#    > Found 1 clusters in hypercube 1177.
#    > Found 1 clusters in hypercube 1178.
# Cube_1179 is empty.
#
#    > Found 1 clusters in hypercube 1180.
#    > Found 1 clusters in hypercube 1181.
#    > Found 1 clusters in hypercube 1182.
# Cube_1183 is empty.
#
# Cube_1184 is empty.
#
#    > Found 0 clusters in hypercube 1185.
# Cube_1186 is empty.
#
#    > Found 0 clusters in hypercube 1187.
# Cube_1188 is empty.
#
# Cube_1189 is empty.
#
# Cube_1190 is empty.
#
#    > Found 2 clusters in hypercube 1191.
#    > Found 0 clusters in hypercube 1192.
# Cube_1193 is empty.
#
# Cube_1194 is empty.
#
#    > Found 2 clusters in hypercube 1195.
#    > Found 1 clusters in hypercube 1196.
#    > Found 0 clusters in hypercube 1197.
#    > Found 1 clusters in hypercube 1198.
#    > Found 1 clusters in hypercube 1199.
#    > Found 2 clusters in hypercube 1200.
#    > Found 2 clusters in hypercube 1201.
# Cube_1202 is empty.
#
# Cube_1203 is empty.
#
#    > Found 1 clusters in hypercube 1204.
#    > Found 1 clusters in hypercube 1205.
#    > Found 1 clusters in hypercube 1206.
#    > Found 2 clusters in hypercube 1207.
#    > Found 1 clusters in hypercube 1208.
# Cube_1209 is empty.
#
# Cube_1210 is empty.
#
#    > Found 0 clusters in hypercube 1211.
# Cube_1212 is empty.
#
#    > Found 0 clusters in hypercube 1213.
# Cube_1214 is empty.
#
# Cube_1215 is empty.
#
#    > Found 0 clusters in hypercube 1216.
# Cube_1217 is empty.
#
# Cube_1218 is empty.
#
#    > Found 0 clusters in hypercube 1219.
# Cube_1220 is empty.
#
# Cube_1221 is empty.
#
# Cube_1222 is empty.
#
# Cube_1223 is empty.
#
# Cube_1224 is empty.
#
# Cube_1225 is empty.
#
# Cube_1226 is empty.
#
# Cube_1227 is empty.
#
# Cube_1228 is empty.
#
# Cube_1229 is empty.
#
# Cube_1230 is empty.
#
# Cube_1231 is empty.
#
# Cube_1232 is empty.
#
# Cube_1233 is empty.
#
# Cube_1234 is empty.
#
# Cube_1235 is empty.
#
# Cube_1236 is empty.
#
# Cube_1237 is empty.
#
#    > Found 0 clusters in hypercube 1238.
# Cube_1239 is empty.
#
# Cube_1240 is empty.
#
#    > Found 0 clusters in hypercube 1241.
#    > Found 1 clusters in hypercube 1242.
#    > Found 1 clusters in hypercube 1243.
#    > Found 1 clusters in hypercube 1244.
# Cube_1245 is empty.
#
# Cube_1246 is empty.
#
# Cube_1247 is empty.
#
#    > Found 1 clusters in hypercube 1248.
#    > Found 1 clusters in hypercube 1249.
#    > Found 2 clusters in hypercube 1250.
#    > Found 1 clusters in hypercube 1251.
# Cube_1252 is empty.
#
# Cube_1253 is empty.
#
#    > Found 1 clusters in hypercube 1254.
#    > Found 1 clusters in hypercube 1255.
#    > Found 2 clusters in hypercube 1256.
#    > Found 1 clusters in hypercube 1257.
# Cube_1258 is empty.
#
# Cube_1259 is empty.
#
#    > Found 1 clusters in hypercube 1260.
#    > Found 1 clusters in hypercube 1261.
#    > Found 1 clusters in hypercube 1262.
#    > Found 2 clusters in hypercube 1263.
# Cube_1264 is empty.
#
# Cube_1265 is empty.
#
# Cube_1266 is empty.
#
#    > Found 1 clusters in hypercube 1267.
#    > Found 2 clusters in hypercube 1268.
#    > Found 0 clusters in hypercube 1269.
# Cube_1270 is empty.
#
# Cube_1271 is empty.
#
#    > Found 0 clusters in hypercube 1272.
#    > Found 1 clusters in hypercube 1273.
#    > Found 0 clusters in hypercube 1274.
#    > Found 0 clusters in hypercube 1275.
# Cube_1276 is empty.
#
# Cube_1277 is empty.
#
# Cube_1278 is empty.
#
# Cube_1279 is empty.
#
# Cube_1280 is empty.
#
# Cube_1281 is empty.
#
# Cube_1282 is empty.
#
# Cube_1283 is empty.
#
# Cube_1284 is empty.
#
# Cube_1285 is empty.
#
# Cube_1286 is empty.
#
# Cube_1287 is empty.
#
# Cube_1288 is empty.
#
# Cube_1289 is empty.
#
# Cube_1290 is empty.
#
#    > Found 1 clusters in hypercube 1291.
# Cube_1292 is empty.
#
#    > Found 1 clusters in hypercube 1293.
#    > Found 1 clusters in hypercube 1294.
#    > Found 1 clusters in hypercube 1295.
#    > Found 1 clusters in hypercube 1296.
#    > Found 0 clusters in hypercube 1297.
# Cube_1298 is empty.
#
#    > Found 0 clusters in hypercube 1299.
#    > Found 1 clusters in hypercube 1300.
#    > Found 2 clusters in hypercube 1301.
#    > Found 2 clusters in hypercube 1302.
#    > Found 2 clusters in hypercube 1303.
#    > Found 0 clusters in hypercube 1304.
# Cube_1305 is empty.
#
#    > Found 2 clusters in hypercube 1306.
#    > Found 1 clusters in hypercube 1307.
#    > Found 2 clusters in hypercube 1308.
#    > Found 2 clusters in hypercube 1309.
#    > Found 1 clusters in hypercube 1310.
# Cube_1311 is empty.
#
# Cube_1312 is empty.
#
#    > Found 0 clusters in hypercube 1313.
#    > Found 0 clusters in hypercube 1314.
#    > Found 1 clusters in hypercube 1315.
#    > Found 3 clusters in hypercube 1316.
#    > Found 0 clusters in hypercube 1317.
# Cube_1318 is empty.
#
#    > Found 0 clusters in hypercube 1319.
# Cube_1320 is empty.
#
#    > Found 1 clusters in hypercube 1321.
#    > Found 0 clusters in hypercube 1322.
# Cube_1323 is empty.
#
# Cube_1324 is empty.
#
# Cube_1325 is empty.
#
#    > Found 1 clusters in hypercube 1326.
# Cube_1327 is empty.
#
# Cube_1328 is empty.
#
# Cube_1329 is empty.
#
# Cube_1330 is empty.
#
# Cube_1331 is empty.
#
#    > Found 1 clusters in hypercube 1332.
#    > Found 1 clusters in hypercube 1333.
#    > Found 1 clusters in hypercube 1334.
#    > Found 1 clusters in hypercube 1335.
# Cube_1336 is empty.
#
# Cube_1337 is empty.
#
# Cube_1338 is empty.
#
# Cube_1339 is empty.
#
# Cube_1340 is empty.
#
# Cube_1341 is empty.
#
# Cube_1342 is empty.
#
# Cube_1343 is empty.
#
# Cube_1344 is empty.
#
# Cube_1345 is empty.
#
# Cube_1346 is empty.
#
# Cube_1347 is empty.
#
# Cube_1348 is empty.
#
# Cube_1349 is empty.
#
# Cube_1350 is empty.
#
# Cube_1351 is empty.
#
# Cube_1352 is empty.
#
# Cube_1353 is empty.
#
# Cube_1354 is empty.
#
#    > Found 0 clusters in hypercube 1355.
#    > Found 0 clusters in hypercube 1356.
# Cube_1357 is empty.
#
# Cube_1358 is empty.
#
#    > Found 0 clusters in hypercube 1359.
#    > Found 1 clusters in hypercube 1360.
#    > Found 1 clusters in hypercube 1361.
# Cube_1362 is empty.
#
# Cube_1363 is empty.
#
#    > Found 0 clusters in hypercube 1364.
#    > Found 1 clusters in hypercube 1365.
#    > Found 1 clusters in hypercube 1366.
#    > Found 1 clusters in hypercube 1367.
# Cube_1368 is empty.
#
# Cube_1369 is empty.
#
#    > Found 1 clusters in hypercube 1370.
#    > Found 1 clusters in hypercube 1371.
#    > Found 2 clusters in hypercube 1372.
#    > Found 1 clusters in hypercube 1373.
# Cube_1374 is empty.
#
# Cube_1375 is empty.
#
#    > Found 1 clusters in hypercube 1376.
# Cube_1377 is empty.
#
#    > Found 1 clusters in hypercube 1378.
#    > Found 1 clusters in hypercube 1379.
# Cube_1380 is empty.
#
# Cube_1381 is empty.
#
# Cube_1382 is empty.
#
# Cube_1383 is empty.
#
# Cube_1384 is empty.
#
# Cube_1385 is empty.
#
# Cube_1386 is empty.
#
# Cube_1387 is empty.
#
#    > Found 0 clusters in hypercube 1388.
#    > Found 1 clusters in hypercube 1389.
# Cube_1390 is empty.
#
# Cube_1391 is empty.
#
#    > Found 0 clusters in hypercube 1392.
#    > Found 1 clusters in hypercube 1393.
#    > Found 2 clusters in hypercube 1394.
#    > Found 0 clusters in hypercube 1395.
# Cube_1396 is empty.
#
#    > Found 0 clusters in hypercube 1397.
#    > Found 2 clusters in hypercube 1398.
#    > Found 1 clusters in hypercube 1399.
#    > Found 2 clusters in hypercube 1400.
# Cube_1401 is empty.
#
#    > Found 0 clusters in hypercube 1402.
#    > Found 1 clusters in hypercube 1403.
#    > Found 2 clusters in hypercube 1404.
#    > Found 2 clusters in hypercube 1405.
#    > Found 2 clusters in hypercube 1406.
#    > Found 1 clusters in hypercube 1407.
#    > Found 0 clusters in hypercube 1408.
#    > Found 1 clusters in hypercube 1409.
#    > Found 0 clusters in hypercube 1410.
#    > Found 1 clusters in hypercube 1411.
#    > Found 2 clusters in hypercube 1412.
#    > Found 0 clusters in hypercube 1413.
# Cube_1414 is empty.
#
#    > Found 0 clusters in hypercube 1415.
# Cube_1416 is empty.
#
#    > Found 0 clusters in hypercube 1417.
# Cube_1418 is empty.
#
# Cube_1419 is empty.
#
# Cube_1420 is empty.
#
# Cube_1421 is empty.
#
# Cube_1422 is empty.
#
# Cube_1423 is empty.
#
# Cube_1424 is empty.
#
#    > Found 1 clusters in hypercube 1425.
# Cube_1426 is empty.
#
# Cube_1427 is empty.
#
# Cube_1428 is empty.
#
#    > Found 1 clusters in hypercube 1429.
# Cube_1430 is empty.
#
# Cube_1431 is empty.
#
# Cube_1432 is empty.
#
# Cube_1433 is empty.
#
# Cube_1434 is empty.
#
# Cube_1435 is empty.
#
# Cube_1436 is empty.
#
# Cube_1437 is empty.
#
# Cube_1438 is empty.
#
# Cube_1439 is empty.
#
# Cube_1440 is empty.
#
# Cube_1441 is empty.
#
# Cube_1442 is empty.
#
# Cube_1443 is empty.
#
#    > Found 0 clusters in hypercube 1444.
# Cube_1445 is empty.
#
# Cube_1446 is empty.
#
#    > Found 2 clusters in hypercube 1447.
#    > Found 1 clusters in hypercube 1448.
#    > Found 1 clusters in hypercube 1449.
#    > Found 0 clusters in hypercube 1450.
#    > Found 1 clusters in hypercube 1451.
#    > Found 1 clusters in hypercube 1452.
# Cube_1453 is empty.
#
#    > Found 1 clusters in hypercube 1454.
#    > Found 1 clusters in hypercube 1455.
#    > Found 1 clusters in hypercube 1456.
#    > Found 1 clusters in hypercube 1457.
#    > Found 0 clusters in hypercube 1458.
#    > Found 1 clusters in hypercube 1459.
#    > Found 1 clusters in hypercube 1460.
#    > Found 1 clusters in hypercube 1461.
#    > Found 2 clusters in hypercube 1462.
#    > Found 2 clusters in hypercube 1463.
#    > Found 0 clusters in hypercube 1464.
# Cube_1465 is empty.
#
# Cube_1466 is empty.
#
#    > Found 1 clusters in hypercube 1467.
#    > Found 2 clusters in hypercube 1468.
#    > Found 0 clusters in hypercube 1469.
# Cube_1470 is empty.
#
# Cube_1471 is empty.
#
# Cube_1472 is empty.
#
# Cube_1473 is empty.
#
#    > Found 0 clusters in hypercube 1474.
# Cube_1475 is empty.
#
# Cube_1476 is empty.
#
#    > Found 1 clusters in hypercube 1477.
# Cube_1478 is empty.
#
# Cube_1479 is empty.
#
# Cube_1480 is empty.
#
# Cube_1481 is empty.
#
# Cube_1482 is empty.
#
# Cube_1483 is empty.
#
# Cube_1484 is empty.
#
# Cube_1485 is empty.
#
#    > Found 1 clusters in hypercube 1486.
# Cube_1487 is empty.
#
# Cube_1488 is empty.
#
# Cube_1489 is empty.
#
# Cube_1490 is empty.
#
# Cube_1491 is empty.
#
# Cube_1492 is empty.
#
#    > Found 1 clusters in hypercube 1493.
# Cube_1494 is empty.
#
#    > Found 1 clusters in hypercube 1495.
#    > Found 1 clusters in hypercube 1496.
#    > Found 0 clusters in hypercube 1497.
#    > Found 2 clusters in hypercube 1498.
# Cube_1499 is empty.
#
#    > Found 0 clusters in hypercube 1500.
#    > Found 2 clusters in hypercube 1501.
#    > Found 1 clusters in hypercube 1502.
#    > Found 1 clusters in hypercube 1503.
#    > Found 0 clusters in hypercube 1504.
# Cube_1505 is empty.
#
# Cube_1506 is empty.
#
#    > Found 1 clusters in hypercube 1507.
#    > Found 2 clusters in hypercube 1508.
#    > Found 1 clusters in hypercube 1509.
#    > Found 1 clusters in hypercube 1510.
#    > Found 1 clusters in hypercube 1511.
# Cube_1512 is empty.
#
# Cube_1513 is empty.
#
#    > Found 0 clusters in hypercube 1514.
#    > Found 1 clusters in hypercube 1515.
#    > Found 2 clusters in hypercube 1516.
#    > Found 1 clusters in hypercube 1517.
#    > Found 1 clusters in hypercube 1518.
# Cube_1519 is empty.
#
# Cube_1520 is empty.
#
#    > Found 0 clusters in hypercube 1521.
# Cube_1522 is empty.
#
#    > Found 0 clusters in hypercube 1523.
#    > Found 0 clusters in hypercube 1524.
#    > Found 1 clusters in hypercube 1525.
# Cube_1526 is empty.
#
# Cube_1527 is empty.
#
# Cube_1528 is empty.
#
# Cube_1529 is empty.
#
# Cube_1530 is empty.
#
# Cube_1531 is empty.
#
#    > Found 0 clusters in hypercube 1532.
# Cube_1533 is empty.
#
# Cube_1534 is empty.
#
# Cube_1535 is empty.
#
# Cube_1536 is empty.
#
#    > Found 0 clusters in hypercube 1537.
# Cube_1538 is empty.
#
# Cube_1539 is empty.
#
# Cube_1540 is empty.
#
# Cube_1541 is empty.
#
#    > Found 0 clusters in hypercube 1542.
#    > Found 1 clusters in hypercube 1543.
# Cube_1544 is empty.
#
# Cube_1545 is empty.
#
#    > Found 1 clusters in hypercube 1546.
#    > Found 2 clusters in hypercube 1547.
#    > Found 2 clusters in hypercube 1548.
#    > Found 2 clusters in hypercube 1549.
#    > Found 1 clusters in hypercube 1550.
# Cube_1551 is empty.
#
# Cube_1552 is empty.
#
#    > Found 1 clusters in hypercube 1553.
#    > Found 2 clusters in hypercube 1554.
#    > Found 1 clusters in hypercube 1555.
#    > Found 2 clusters in hypercube 1556.
#    > Found 0 clusters in hypercube 1557.
# Cube_1558 is empty.
#
# Cube_1559 is empty.
#
# Cube_1560 is empty.
#
#    > Found 0 clusters in hypercube 1561.
#    > Found 1 clusters in hypercube 1562.
#    > Found 1 clusters in hypercube 1563.
#    > Found 1 clusters in hypercube 1564.
# Cube_1565 is empty.
#
# Cube_1566 is empty.
#
# Cube_1567 is empty.
#
# Cube_1568 is empty.
#
#    > Found 1 clusters in hypercube 1569.
#    > Found 2 clusters in hypercube 1570.
#    > Found 2 clusters in hypercube 1571.
#    > Found 1 clusters in hypercube 1572.
# Cube_1573 is empty.
#
# Cube_1574 is empty.
#
# Cube_1575 is empty.
#
#    > Found 0 clusters in hypercube 1576.
#    > Found 0 clusters in hypercube 1577.
#    > Found 0 clusters in hypercube 1578.
# Cube_1579 is empty.
#
# Cube_1580 is empty.
#
# Cube_1581 is empty.
#
# Cube_1582 is empty.
#
# Cube_1583 is empty.
#
# Cube_1584 is empty.
#
#    > Found 0 clusters in hypercube 1585.
# Cube_1586 is empty.
#
# Cube_1587 is empty.
#
# Cube_1588 is empty.
#
# Cube_1589 is empty.
#
#    > Found 0 clusters in hypercube 1590.
#    > Found 1 clusters in hypercube 1591.
#    > Found 0 clusters in hypercube 1592.
# Cube_1593 is empty.
#
# Cube_1594 is empty.
#
# Cube_1595 is empty.
#
# Cube_1596 is empty.
#
# Cube_1597 is empty.
#
#    > Found 1 clusters in hypercube 1598.
#    > Found 2 clusters in hypercube 1599.
#    > Found 2 clusters in hypercube 1600.
#    > Found 1 clusters in hypercube 1601.
#    > Found 1 clusters in hypercube 1602.
# Cube_1603 is empty.
#
#    > Found 0 clusters in hypercube 1604.
#    > Found 1 clusters in hypercube 1605.
#    > Found 2 clusters in hypercube 1606.
#    > Found 1 clusters in hypercube 1607.
#    > Found 2 clusters in hypercube 1608.
# Cube_1609 is empty.
#
# Cube_1610 is empty.
#
#    > Found 1 clusters in hypercube 1611.
#    > Found 3 clusters in hypercube 1612.
#    > Found 1 clusters in hypercube 1613.
#    > Found 2 clusters in hypercube 1614.
# Cube_1615 is empty.
#
# Cube_1616 is empty.
#
# Cube_1617 is empty.
#
#    > Found 1 clusters in hypercube 1618.
#    > Found 1 clusters in hypercube 1619.
#    > Found 2 clusters in hypercube 1620.
#    > Found 1 clusters in hypercube 1621.
# Cube_1622 is empty.
#
# Cube_1623 is empty.
#
#    > Found 2 clusters in hypercube 1624.
#    > Found 1 clusters in hypercube 1625.
#    > Found 0 clusters in hypercube 1626.
# Cube_1627 is empty.
#
# Cube_1628 is empty.
#
# Cube_1629 is empty.
#
# Cube_1630 is empty.
#
# Cube_1631 is empty.
#
# Cube_1632 is empty.
#
# Cube_1633 is empty.
#
# Cube_1634 is empty.
#
#    > Found 1 clusters in hypercube 1635.
#    > Found 1 clusters in hypercube 1636.
# Cube_1637 is empty.
#
# Cube_1638 is empty.
#
#    > Found 1 clusters in hypercube 1639.
#    > Found 1 clusters in hypercube 1640.
#    > Found 2 clusters in hypercube 1641.
#    > Found 0 clusters in hypercube 1642.
#    > Found 0 clusters in hypercube 1643.
# Cube_1644 is empty.
#
# Cube_1645 is empty.
#
#    > Found 1 clusters in hypercube 1646.
#    > Found 1 clusters in hypercube 1647.
#    > Found 2 clusters in hypercube 1648.
#    > Found 2 clusters in hypercube 1649.
#    > Found 1 clusters in hypercube 1650.
#    > Found 1 clusters in hypercube 1651.
# Cube_1652 is empty.
#
#    > Found 0 clusters in hypercube 1653.
#    > Found 2 clusters in hypercube 1654.
#    > Found 2 clusters in hypercube 1655.
#    > Found 2 clusters in hypercube 1656.
# Cube_1657 is empty.
#
# Cube_1658 is empty.
#
#    > Found 2 clusters in hypercube 1659.
#    > Found 1 clusters in hypercube 1660.
#    > Found 2 clusters in hypercube 1661.
# Cube_1662 is empty.
#
#    > Found 0 clusters in hypercube 1663.
#    > Found 0 clusters in hypercube 1664.
#    > Found 1 clusters in hypercube 1665.
# Cube_1666 is empty.
#
# Cube_1667 is empty.
#
# Cube_1668 is empty.
#
# Cube_1669 is empty.
#
# Cube_1670 is empty.
#
# Cube_1671 is empty.
#
#    > Found 1 clusters in hypercube 1672.
# Cube_1673 is empty.
#
# Cube_1674 is empty.
#
#    > Found 0 clusters in hypercube 1675.
#    > Found 2 clusters in hypercube 1676.
#    > Found 1 clusters in hypercube 1677.
#    > Found 0 clusters in hypercube 1678.
#    > Found 0 clusters in hypercube 1679.
# Cube_1680 is empty.
#
# Cube_1681 is empty.
#
# Cube_1682 is empty.
#
#    > Found 0 clusters in hypercube 1683.
#    > Found 2 clusters in hypercube 1684.
#    > Found 1 clusters in hypercube 1685.
#    > Found 1 clusters in hypercube 1686.
#    > Found 1 clusters in hypercube 1687.
#    > Found 1 clusters in hypercube 1688.
#    > Found 2 clusters in hypercube 1689.
#    > Found 1 clusters in hypercube 1690.
#    > Found 1 clusters in hypercube 1691.
# Cube_1692 is empty.
#
# Cube_1693 is empty.
#
#    > Found 1 clusters in hypercube 1694.
#    > Found 0 clusters in hypercube 1695.
#    > Found 1 clusters in hypercube 1696.
#    > Found 1 clusters in hypercube 1697.
# Cube_1698 is empty.
#
# Cube_1699 is empty.
#
#    > Found 0 clusters in hypercube 1700.
# Cube_1701 is empty.
#
# Cube_1702 is empty.
#
# Cube_1703 is empty.
#
#    > Found 1 clusters in hypercube 1704.
# Cube_1705 is empty.
#
# Cube_1706 is empty.
#
# Cube_1707 is empty.
#
#    > Found 1 clusters in hypercube 1708.
# Cube_1709 is empty.
#
# Cube_1710 is empty.
#
#    > Found 1 clusters in hypercube 1711.
# Cube_1712 is empty.
#
# Cube_1713 is empty.
#
#    > Found 1 clusters in hypercube 1714.
# Cube_1715 is empty.
#
# Cube_1716 is empty.
#
#
# Created 3053 edges and 805 nodes in 0:00:03.348873.
# Wrote visualization to: Torus Gaussian & l2norm.html
# '<!DOCTYPE html>\n<html>\n\n<head>\n  <meta charset="utf-8">\n  <meta name="generator" content="KeplerMapper">\n  <title>Gaussian & l2norm lenses | KeplerMapper</title>\n\n  <link rel="icon" type="image/png" href="http://i.imgur.com/axOG6GJ.jpg" />\n\n  <link href=\'https://fonts.googleapis.com/css?family=Roboto+Mono:700,300\' rel=\'stylesheet\' type=\'text/css\'>\n  <style>* {\n  margin: 0;\n  padding: 0;\n}\n\nhtml, body {\n  height: 100%;\n}\n\nbody {\n  font-family: "Roboto Mono", "Helvetica", sans-serif;\n  font-size: 14px;\n}\n\n#logo {\n  width:  85px;\n  height: 85px;\n}\n\n#display {\n  color: #95A5A6;\n  background: #212121;\n}\n\n#header {\n  background: #111111;\n}\n\n#print {\n  color: #000;\n  background: #FFF;\n}\n\nh1 {\n  font-size: 21px;\n  font-weight: 300;\n  font-weight: 300;\n}\n\nh2 {\n  font-size: 18px;\n  padding-bottom: 20px;\n  font-weight: 300;\n}\n\nh3 {\n  font-size: 14px;\n  font-weight: 700;\n  text-transform: uppercase;\n}\n\nh4 {\n  font-size: 13px;\n  font-weight: 700;\n  text-transform: uppercase;\n  padding-bottom:0px;\n}\n\n\n#meta_content h3 {\n  float: left;\n  padding-right: 8px;\n}\n\np, #tooltip_content h3, ol, ul, table {\n  padding-bottom: 10px;\n}\n\nol, ul {\n  padding-left: 20px;\n}\n\nol b {\n  display: block;\n}\n\na {\n  color: #16a085;\n  text-decoration: none;\n}\n\n.pane {\n  position: relative;\n}\n\n.pane-left {\n  float: left;\n}\n\n.pane-right {\n  float: right;\n}\n\na:hover {\n  color: #2ecc71;\n}\n\n.banner {\n  /* height: 35px; */\n  padding: 10px 0px;\n}\n\n\n#print #header {\n  background: #FFF;\n}\n\n\n#canvas {\n  width: 100%;\n}\n\n#svg {\n  position: absolute;\n}\n\n#toolbar {\n  padding-top: 5px;\n  margin-bottom: 5px;\n  width: 100%;\n}\n\n#display #toolbar {\n}\n\n#display .banner {\n  border-top: 1px solid #000;\n}\n\n.inline-block {\n  display: inline-block;\n}\n\n.tool_item {\n  padding-left: 10px;\n  padding-right: 10px;\n}\n\n.pane_content {\n  width: 300px;\n  height:100%;\n  padding: 20px;\n  overflow: auto;\n  display: none;\n}\n\n.pane {\n  z-index: 1;\n}\n\n#display .pane_content {\n  background: #191919;\n}\n\n#print .pane_content{\n  background: #FFF;\n}\n\n#meta_content::-webkit-scrollbar, #tooltip_content::-webkit-scrollbar {\n  width: 1em;\n}\n\n#meta_content::-webkit-scrollbar-track, #tooltip_content::-webkit-scrollbar-track {\n  -webkit-box-shadow: inset 0 0 6px rgba(0, 0, 0, 0.3);\n}\n\n#meta_content::-webkit-scrollbar-thumb, #tooltip_content::-webkit-scrollbar-thumb {\n  background-color: darkgrey;\n  outline: 1px solid slategrey;\n}\n\n.histogram {\n  display: block;\n  height: 100px;\n  padding-top: 50px;\n  clear: both;\n}\n\n#display .histogram {\n  opacity: 0.68;\n}\n\n.bin {\n  width: 10%;\n  float: left;\n}\n\n.bin div {\n  font-size: 10px;\n  display: block;\n  width: 35px;\n  margin-top: -30px;\n  text-align: right;\n  margin-left: -3px;\n  -webkit-transform: rotate(-90deg);\n  -moz-transform: rotate(-90deg);\n  -ms-transform: rotate(-90deg);\n  -o-transform: rotate(-90deg);\n}\n\n.histogram:hover {\n  opacity: 1.;\n}\n\n#display .circle {\n  stroke-opacity: 0.18;\n  stroke-width: 7px;\n  stroke: #000;\n}\n\n#print .circle {\n  stroke-opacity: 1;\n  stroke-width: 2px;\n  stroke: #000;\n  stroke-linecap: round;\n}\n\n#print .link {\n  stroke: #000;\n}\n\n#display .link {\n  stroke: rgba(160, 160, 160, 0.5);\n}\n\ntable {\n  border-collapse: collapse;\n  display: table;\n  width: 100%;\n  margin-bottom: 20px;\n}\n\ntd, th {\n  padding: 5px;\n  text-align: left;\n}\n\n#display th {\n  background: #212121\n}\n\ntd {\n  border-bottom: 1px solid #111;\n}\n\n.highlight {\n  filter: url(#drop-shadow-pulse);\n}\n\n.control-row {\n  padding: 5px 0px;\n}\n\n.btn {\n  display: inline-block;\n  padding: 0.35em 1.2em;\n  border: 0.1em solid #FFFFFF;\n  margin: 0 0.3em 0.3em 0;\n  border-radius: 0.12em;\n  box-sizing: border-box;\n  text-decoration: none;\n  background-color: transparent;\n  font-weight: 300;\n  color: #FFFFFF;\n  text-align: c ...

# %% [markdown]
# ## ¿Qué otros métodos de agrupamiento podemos usar?

# %% [markdown]
# Algoritmos de agrupamiento compatibles con Scikit-learn API. Debe tener "fit" and "predict": https://scikit-learn.org/stable/modules/clustering.html#

# %% [markdown]
# # KMeans

# %% [markdown]
# El algoritmo KMeans agrupa los datos intentado separarlos en n grupos de igual varianza. El algoritmo requiere que se especifique el número de clusters. El algoritmo KMeans divide al conjunto de $N$ puntos, $X$, en $K$ clusters ajenos $C$, cada uno descrito por el promedio $\mu_j$ de las muestras en el cluster. Los promedios son llamados baricentros o centroides, los cuales, en general no son puntos de $X$, aunque sí viven en el mismo espacio: https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html#sklearn.cluster.KMeans
#
# El algoritmo tiende a elegir los centroides que minimizan la "inercia" o la suma de los cuadrados a los elementos del cluster:
#
# $\sum\limits_{i=0}^n\min\limits_{\mu_j\in C}(\Vert x_i-\mu_j\Vert^2)$
#
# #### Parámetros:
# * n_clusters (int, default=8): número de clusters (así como el número de centroides)
# * random_state (int, default=None): Número de generación aleatoria de centroides.

# %%
lens = mapper.fit_transform(torus)

graph = mapper.map(
    lens,
    torus,
    clusterer=sklearn.cluster.KMeans(n_clusters=1, random_state=11),
    cover=km.Cover(n_cubes=15, perc_overlap=0.3),
)

mapper.visualize(graph, path_html="Torus Kmeans.html",
                    title="Kmeans(n_clusters=1)")
# Out:
# ..Composing projection pipeline of length 1:
# 	Projections: sum
# 	Distance matrices: False
# 	Scalers: MinMaxScaler()
# ..Projecting on data shaped (2000, 3)
#
# ..Projecting data using: sum
#
# ..Scaling with: MinMaxScaler()
#
# Mapping on data shaped (2000, 3) using lens shaped (2000, 1)
#
# Minimal points in hypercube before clustering: 1
# Creating 15 hypercubes.
#    > Found 1 clusters in hypercube 0.
#    > Found 1 clusters in hypercube 1.
#    > Found 1 clusters in hypercube 2.
#    > Found 1 clusters in hypercube 3.
#    > Found 1 clusters in hypercube 4.
#    > Found 1 clusters in hypercube 5.
#    > Found 1 clusters in hypercube 6.
#    > Found 1 clusters in hypercube 7.
#    > Found 1 clusters in hypercube 8.
#    > Found 1 clusters in hypercube 9.
#    > Found 1 clusters in hypercube 10.
#    > Found 1 clusters in hypercube 11.
#    > Found 1 clusters in hypercube 12.
#    > Found 1 clusters in hypercube 13.
#    > Found 1 clusters in hypercube 14.
#
# Created 14 edges and 15 nodes in 0:00:00.096904.
# Wrote visualization to: Torus Kmeans.html
# '<!DOCTYPE html>\n<html>\n\n<head>\n  <meta charset="utf-8">\n  <meta name="generator" content="KeplerMapper">\n  <title>Kmeans(n_clusters=1) | KeplerMapper</title>\n\n  <link rel="icon" type="image/png" href="http://i.imgur.com/axOG6GJ.jpg" />\n\n  <link href=\'https://fonts.googleapis.com/css?family=Roboto+Mono:700,300\' rel=\'stylesheet\' type=\'text/css\'>\n  <style>* {\n  margin: 0;\n  padding: 0;\n}\n\nhtml, body {\n  height: 100%;\n}\n\nbody {\n  font-family: "Roboto Mono", "Helvetica", sans-serif;\n  font-size: 14px;\n}\n\n#logo {\n  width:  85px;\n  height: 85px;\n}\n\n#display {\n  color: #95A5A6;\n  background: #212121;\n}\n\n#header {\n  background: #111111;\n}\n\n#print {\n  color: #000;\n  background: #FFF;\n}\n\nh1 {\n  font-size: 21px;\n  font-weight: 300;\n  font-weight: 300;\n}\n\nh2 {\n  font-size: 18px;\n  padding-bottom: 20px;\n  font-weight: 300;\n}\n\nh3 {\n  font-size: 14px;\n  font-weight: 700;\n  text-transform: uppercase;\n}\n\nh4 {\n  font-size: 13px;\n  font-weight: 700;\n  text-transform: uppercase;\n  padding-bottom:0px;\n}\n\n\n#meta_content h3 {\n  float: left;\n  padding-right: 8px;\n}\n\np, #tooltip_content h3, ol, ul, table {\n  padding-bottom: 10px;\n}\n\nol, ul {\n  padding-left: 20px;\n}\n\nol b {\n  display: block;\n}\n\na {\n  color: #16a085;\n  text-decoration: none;\n}\n\n.pane {\n  position: relative;\n}\n\n.pane-left {\n  float: left;\n}\n\n.pane-right {\n  float: right;\n}\n\na:hover {\n  color: #2ecc71;\n}\n\n.banner {\n  /* height: 35px; */\n  padding: 10px 0px;\n}\n\n\n#print #header {\n  background: #FFF;\n}\n\n\n#canvas {\n  width: 100%;\n}\n\n#svg {\n  position: absolute;\n}\n\n#toolbar {\n  padding-top: 5px;\n  margin-bottom: 5px;\n  width: 100%;\n}\n\n#display #toolbar {\n}\n\n#display .banner {\n  border-top: 1px solid #000;\n}\n\n.inline-block {\n  display: inline-block;\n}\n\n.tool_item {\n  padding-left: 10px;\n  padding-right: 10px;\n}\n\n.pane_content {\n  width: 300px;\n  height:100%;\n  padding: 20px;\n  overflow: auto;\n  display: none;\n}\n\n.pane {\n  z-index: 1;\n}\n\n#display .pane_content {\n  background: #191919;\n}\n\n#print .pane_content{\n  background: #FFF;\n}\n\n#meta_content::-webkit-scrollbar, #tooltip_content::-webkit-scrollbar {\n  width: 1em;\n}\n\n#meta_content::-webkit-scrollbar-track, #tooltip_content::-webkit-scrollbar-track {\n  -webkit-box-shadow: inset 0 0 6px rgba(0, 0, 0, 0.3);\n}\n\n#meta_content::-webkit-scrollbar-thumb, #tooltip_content::-webkit-scrollbar-thumb {\n  background-color: darkgrey;\n  outline: 1px solid slategrey;\n}\n\n.histogram {\n  display: block;\n  height: 100px;\n  padding-top: 50px;\n  clear: both;\n}\n\n#display .histogram {\n  opacity: 0.68;\n}\n\n.bin {\n  width: 10%;\n  float: left;\n}\n\n.bin div {\n  font-size: 10px;\n  display: block;\n  width: 35px;\n  margin-top: -30px;\n  text-align: right;\n  margin-left: -3px;\n  -webkit-transform: rotate(-90deg);\n  -moz-transform: rotate(-90deg);\n  -ms-transform: rotate(-90deg);\n  -o-transform: rotate(-90deg);\n}\n\n.histogram:hover {\n  opacity: 1.;\n}\n\n#display .circle {\n  stroke-opacity: 0.18;\n  stroke-width: 7px;\n  stroke: #000;\n}\n\n#print .circle {\n  stroke-opacity: 1;\n  stroke-width: 2px;\n  stroke: #000;\n  stroke-linecap: round;\n}\n\n#print .link {\n  stroke: #000;\n}\n\n#display .link {\n  stroke: rgba(160, 160, 160, 0.5);\n}\n\ntable {\n  border-collapse: collapse;\n  display: table;\n  width: 100%;\n  margin-bottom: 20px;\n}\n\ntd, th {\n  padding: 5px;\n  text-align: left;\n}\n\n#display th {\n  background: #212121\n}\n\ntd {\n  border-bottom: 1px solid #111;\n}\n\n.highlight {\n  filter: url(#drop-shadow-pulse);\n}\n\n.control-row {\n  padding: 5px 0px;\n}\n\n.btn {\n  display: inline-block;\n  padding: 0.35em 1.2em;\n  border: 0.1em solid #FFFFFF;\n  margin: 0 0.3em 0.3em 0;\n  border-radius: 0.12em;\n  box-sizing: border-box;\n  text-decoration: none;\n  background-color: transparent;\n  font-weight: 300;\n  color: #FFFFFF;\n  text-align: cente ...

# %% [markdown]
# # MeanShift:

# %% [markdown]
# El agrupamiento "MeanShift" tiende a buscar "gotas" en una densidad suave de muestras. Es un algoritmo basado en la búsqueda de centroides: https://scikit-learn.org/stable/modules/generated/sklearn.cluster.MeanShift.html#sklearn.cluster.MeanShift

# %% [markdown]
# ### Parámetros
# * bandwidth (float, default=None): Ancho de banda para el kernel.
# * cluster_all (bool, default=True): Todos los puntos son agrupados, incluyendo aquellos que no están en algún núcleo, asignándoles el núcleo más cercano.

# %%
from sklearn.cluster import MeanShift

# Fit MeanShift to your data
mean_shift_model = MeanShift(bandwidth=2).fit(torus)

# Use the output of MeanShift as the lens
lens = mean_shift_model.predict(torus)

graph = mapper.map(
    lens,
    torus,
    clusterer=sklearn.cluster.MeanShift(bandwidth=3),
    cover=km.Cover(n_cubes=25, perc_overlap=0.5),
)

mapper.visualize(graph, path_html="Torus MeanShift.html",
                 title="MeanShift")
# Out:
# Mapping on data shaped (2000, 3) using lens shaped (2000,)
#
# Minimal points in hypercube before clustering: 2
# Creating 25 hypercubes.
#    > Found 3 clusters in hypercube 0.
#    > Found 3 clusters in hypercube 1.
#    > Found 3 clusters in hypercube 2.
#    > Found 3 clusters in hypercube 3.
#    > Found 2 clusters in hypercube 4.
#    > Found 3 clusters in hypercube 5.
#    > Found 3 clusters in hypercube 6.
#    > Found 3 clusters in hypercube 7.
#    > Found 3 clusters in hypercube 8.
#    > Found 2 clusters in hypercube 9.
#    > Found 2 clusters in hypercube 10.
#    > Found 2 clusters in hypercube 11.
#    > Found 2 clusters in hypercube 12.
#    > Found 3 clusters in hypercube 13.
#    > Found 3 clusters in hypercube 14.
#    > Found 3 clusters in hypercube 15.
#    > Found 3 clusters in hypercube 16.
#    > Found 3 clusters in hypercube 17.
#    > Found 3 clusters in hypercube 18.
#    > Found 3 clusters in hypercube 19.
#    > Found 2 clusters in hypercube 20.
#    > Found 2 clusters in hypercube 21.
#    > Found 2 clusters in hypercube 22.
#    > Found 2 clusters in hypercube 23.
#    > Found 2 clusters in hypercube 24.
#
# Created 34 edges and 65 nodes in 0:00:03.825872.
# Wrote visualization to: Torus MeanShift.html
# '<!DOCTYPE html>\n<html>\n\n<head>\n  <meta charset="utf-8">\n  <meta name="generator" content="KeplerMapper">\n  <title>MeanShift | KeplerMapper</title>\n\n  <link rel="icon" type="image/png" href="http://i.imgur.com/axOG6GJ.jpg" />\n\n  <link href=\'https://fonts.googleapis.com/css?family=Roboto+Mono:700,300\' rel=\'stylesheet\' type=\'text/css\'>\n  <style>* {\n  margin: 0;\n  padding: 0;\n}\n\nhtml, body {\n  height: 100%;\n}\n\nbody {\n  font-family: "Roboto Mono", "Helvetica", sans-serif;\n  font-size: 14px;\n}\n\n#logo {\n  width:  85px;\n  height: 85px;\n}\n\n#display {\n  color: #95A5A6;\n  background: #212121;\n}\n\n#header {\n  background: #111111;\n}\n\n#print {\n  color: #000;\n  background: #FFF;\n}\n\nh1 {\n  font-size: 21px;\n  font-weight: 300;\n  font-weight: 300;\n}\n\nh2 {\n  font-size: 18px;\n  padding-bottom: 20px;\n  font-weight: 300;\n}\n\nh3 {\n  font-size: 14px;\n  font-weight: 700;\n  text-transform: uppercase;\n}\n\nh4 {\n  font-size: 13px;\n  font-weight: 700;\n  text-transform: uppercase;\n  padding-bottom:0px;\n}\n\n\n#meta_content h3 {\n  float: left;\n  padding-right: 8px;\n}\n\np, #tooltip_content h3, ol, ul, table {\n  padding-bottom: 10px;\n}\n\nol, ul {\n  padding-left: 20px;\n}\n\nol b {\n  display: block;\n}\n\na {\n  color: #16a085;\n  text-decoration: none;\n}\n\n.pane {\n  position: relative;\n}\n\n.pane-left {\n  float: left;\n}\n\n.pane-right {\n  float: right;\n}\n\na:hover {\n  color: #2ecc71;\n}\n\n.banner {\n  /* height: 35px; */\n  padding: 10px 0px;\n}\n\n\n#print #header {\n  background: #FFF;\n}\n\n\n#canvas {\n  width: 100%;\n}\n\n#svg {\n  position: absolute;\n}\n\n#toolbar {\n  padding-top: 5px;\n  margin-bottom: 5px;\n  width: 100%;\n}\n\n#display #toolbar {\n}\n\n#display .banner {\n  border-top: 1px solid #000;\n}\n\n.inline-block {\n  display: inline-block;\n}\n\n.tool_item {\n  padding-left: 10px;\n  padding-right: 10px;\n}\n\n.pane_content {\n  width: 300px;\n  height:100%;\n  padding: 20px;\n  overflow: auto;\n  display: none;\n}\n\n.pane {\n  z-index: 1;\n}\n\n#display .pane_content {\n  background: #191919;\n}\n\n#print .pane_content{\n  background: #FFF;\n}\n\n#meta_content::-webkit-scrollbar, #tooltip_content::-webkit-scrollbar {\n  width: 1em;\n}\n\n#meta_content::-webkit-scrollbar-track, #tooltip_content::-webkit-scrollbar-track {\n  -webkit-box-shadow: inset 0 0 6px rgba(0, 0, 0, 0.3);\n}\n\n#meta_content::-webkit-scrollbar-thumb, #tooltip_content::-webkit-scrollbar-thumb {\n  background-color: darkgrey;\n  outline: 1px solid slategrey;\n}\n\n.histogram {\n  display: block;\n  height: 100px;\n  padding-top: 50px;\n  clear: both;\n}\n\n#display .histogram {\n  opacity: 0.68;\n}\n\n.bin {\n  width: 10%;\n  float: left;\n}\n\n.bin div {\n  font-size: 10px;\n  display: block;\n  width: 35px;\n  margin-top: -30px;\n  text-align: right;\n  margin-left: -3px;\n  -webkit-transform: rotate(-90deg);\n  -moz-transform: rotate(-90deg);\n  -ms-transform: rotate(-90deg);\n  -o-transform: rotate(-90deg);\n}\n\n.histogram:hover {\n  opacity: 1.;\n}\n\n#display .circle {\n  stroke-opacity: 0.18;\n  stroke-width: 7px;\n  stroke: #000;\n}\n\n#print .circle {\n  stroke-opacity: 1;\n  stroke-width: 2px;\n  stroke: #000;\n  stroke-linecap: round;\n}\n\n#print .link {\n  stroke: #000;\n}\n\n#display .link {\n  stroke: rgba(160, 160, 160, 0.5);\n}\n\ntable {\n  border-collapse: collapse;\n  display: table;\n  width: 100%;\n  margin-bottom: 20px;\n}\n\ntd, th {\n  padding: 5px;\n  text-align: left;\n}\n\n#display th {\n  background: #212121\n}\n\ntd {\n  border-bottom: 1px solid #111;\n}\n\n.highlight {\n  filter: url(#drop-shadow-pulse);\n}\n\n.control-row {\n  padding: 5px 0px;\n}\n\n.btn {\n  display: inline-block;\n  padding: 0.35em 1.2em;\n  border: 0.1em solid #FFFFFF;\n  margin: 0 0.3em 0.3em 0;\n  border-radius: 0.12em;\n  box-sizing: border-box;\n  text-decoration: none;\n  background-color: transparent;\n  font-weight: 300;\n  color: #FFFFFF;\n  text-align: center;\n  trans ...
